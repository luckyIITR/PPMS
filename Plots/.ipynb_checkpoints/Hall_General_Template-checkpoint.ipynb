# %% [markdown]
# # Sample Name

# %% [markdown]
# How to use Template:
#     i.  Change file Address
#     ii. Set 'truncate' True if the initial data ranges from 0 to Bmax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

# %%
truncate = True # True it contains data from O to Bmax
path = r"C:\Users\Admin\Desktop\Analysis\Plots\A304_SRO_NGO\HALL_CENTRALCONTACT"
filename = 'A304_SRO_NGO_300K.csv'
df = pd.read_csv(os.path.join(path, filename), names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value','multiplier'])
df
# Out:
#         I             B           T        V1        V2        V3        V4  \
# 0   0.001      0.057963  300.000540  7.582568 -7.582120 -7.561257  7.647964
# 1   0.001   1000.483588  299.999666  7.786359 -7.742460 -7.478469  7.552212
# 2   0.001   2000.230005  300.001392  7.963540 -7.933093 -7.329233  7.457163
# 3   0.001   3000.457312  300.000648  8.089307 -8.080447 -7.250974  7.326187
# 4   0.001   4000.360547  300.000758  8.172922 -8.145444 -7.078251  7.162246
# ..    ...           ...         ...       ...       ...       ...       ...
# 72  0.001   6000.174097  300.000816  8.748374 -8.753706 -7.244777  7.325677
# 73  0.001   7000.383496  300.001489  8.936293 -8.945782 -7.130479  7.240835
# 74  0.001   8000.260596  300.000549  9.085102 -9.046231 -7.020332  7.079099
# 75  0.001   9000.379150  300.000854  9.236534 -9.202040 -6.893220  6.996327
# 76  0.001  10000.544971  300.001082  9.335323 -9.308013 -6.787625  6.874719
#
#        Rel_value  multiplier
# 0   3.471000e-07   1000000.0
# 1   4.479000e-07   1000000.0
# 2   5.076000e-07   1000000.0
# 3   5.509000e-07   1000000.0
# 4   5.820000e-07   1000000.0
# ..           ...         ...
# 72  5.568000e-07   1000000.0
# 73  5.469000e-07   1000000.0
# 74  5.520000e-07   1000000.0
# 75  5.263000e-07   1000000.0
# 76  5.488000e-07   1000000.0
#
# [77 rows x 9 columns]

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B','B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I            B  B_int           T        V1        V2        V3  \
# 0  0.001     0.057963      0  300.000540  7.582568 -7.582120 -7.561257
# 1  0.001  1000.483588   1000  299.999666  7.786359 -7.742460 -7.478469
# 2  0.001  2000.230005   2000  300.001392  7.963540 -7.933093 -7.329233
# 3  0.001  3000.457312   3000  300.000648  8.089307 -8.080447 -7.250974
# 4  0.001  4000.360547   4000  300.000758  8.172922 -8.145444 -7.078251
#
#          V4     Rel_value  multiplier
# 0  7.647964  3.471000e-07   1000000.0
# 1  7.552212  4.479000e-07   1000000.0
# 2  7.457163  5.076000e-07   1000000.0
# 3  7.326187  5.509000e-07   1000000.0
# 4  7.162246  5.820000e-07   1000000.0

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ### Truncating intial data (0 to 1 T)

# %%
if(truncate):
    B_max = max(df['B_int'])
    B_max_first_idx = 0
    for i in range(len(df)):
        if df.iloc[i].B_int == B_max:
            B_max_first_idx = i
            break
    print(B_max_first_idx)

    df = df.iloc[B_max_first_idx+1:].copy()
    df.reset_index(inplace = True, drop = True) # resetting index
# Out:
# 10

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 32

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T        V1        V2        V3  \
# 0  0.001  10000.429199  10000  300.000826  8.943632 -8.926101 -6.370625
# 1  0.001   9000.424170   9000  300.000426  8.853747 -8.827567 -6.534637
# 2  0.001   8000.256519   8000  300.001338  8.718759 -8.697445 -6.676893
# 3  0.001   7000.565527   7000  300.001411  8.578956 -8.538250 -6.729288
# 4  0.001   6000.564453   6000  300.001161  8.447988 -8.423157 -6.922978
#
#          V4     Rel_value  multiplier
# 0  6.451802  6.261000e-07   1000000.0
# 1  6.596879  6.124000e-07   1000000.0
# 2  6.728245  6.161000e-07   1000000.0
# 3  6.807171  6.135000e-07   1000000.0
# 4  6.960542  6.134000e-07   1000000.0

# %%
df_inc.head()
# Out:
#         I             B  B_int           T        V1        V2        V3  \
# 33  0.001 -10000.344531 -10000  299.999506  6.461691 -6.451868 -8.857021
# 34  0.001  -9000.584229  -9000  300.001054  6.601538 -6.583706 -8.732974
# 35  0.001  -8000.420654  -8000  300.000293  6.688938 -6.658958 -8.581014
# 36  0.001  -7000.331323  -7000  300.000395  6.764109 -6.742211 -8.436731
# 37  0.001  -6000.313110  -6000  300.000548  6.896867 -6.859981 -8.312103
#
#           V4     Rel_value  multiplier
# 33  8.946896  5.445000e-07   1000000.0
# 34  8.802438  5.466000e-07   1000000.0
# 35  8.627771  5.519000e-07   1000000.0
# 36  8.465304  5.498000e-07   1000000.0
# 37  8.371898  5.399000e-07   1000000.0

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data_dec = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data_dec = data_dec[data_dec['B_int_x'] == -1*data_dec['B_int_y']] # selecting 
data_dec = data_dec[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data_dec.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data_dec.reset_index(inplace = True, drop = True) # resetting index
data_dec.head()
# Out:
#        I      B           T        V1        V2        V3        V4        V5  \
# 0  0.001  10000  300.000826  8.943632 -8.926101 -6.370625  6.451802  6.461691
# 1  0.001   9000  300.000426  8.853747 -8.827567 -6.534637  6.596879  6.601538
# 2  0.001   8000  300.001338  8.718759 -8.697445 -6.676893  6.728245  6.688938
# 3  0.001   7000  300.001411  8.578956 -8.538250 -6.729288  6.807171  6.764109
# 4  0.001   6000  300.001161  8.447988 -8.423157 -6.922978  6.960542  6.896867
#
#          V6        V7        V8  multiplier
# 0 -6.451868 -8.857021  8.946896   1000000.0
# 1 -6.583706 -8.732974  8.802438   1000000.0
# 2 -6.658958 -8.581014  8.627771   1000000.0
# 3 -6.742211 -8.436731  8.465304   1000000.0
# 4 -6.859981 -8.312103  8.371898   1000000.0

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data_dec['RHc'] = (-data_dec['V2'] + data_dec['V1'] - data_dec['V5'] + data_dec['V6'])/(data_dec['I']*data_dec['multiplier'])
data_dec['RHd'] = (-data_dec['V4'] + data_dec['V3'] - data_dec['V7'] + data_dec['V8'])/(data_dec['I']*data_dec['multiplier'])
data_dec['R'] = (data_dec['RHc'] + data_dec['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data_dec['B'],data_dec['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data_dec['B'],data_dec['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data_dec['B'],data_dec['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data_inc = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data_inc = data_inc[data_inc['B_int_x'] == -1*data_inc['B_int_y']] # selecting 
data_inc = data_inc[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data_inc.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data_inc.reset_index(inplace = True, drop = True) # resetting index
data_inc.head()
# Out:
#        I      B           T        V1        V2        V3        V4        V5  \
# 0  0.001 -10000  299.999506  6.461691 -6.451868 -8.857021  8.946896  8.943632
# 1  0.001  -9000  300.001054  6.601538 -6.583706 -8.732974  8.802438  8.853747
# 2  0.001  -8000  300.000293  6.688938 -6.658958 -8.581014  8.627771  8.718759
# 3  0.001  -7000  300.000395  6.764109 -6.742211 -8.436731  8.465304  8.578956
# 4  0.001  -6000  300.000548  6.896867 -6.859981 -8.312103  8.371898  8.447988
#
#          V6        V7        V8  multiplier
# 0 -8.926101 -6.370625  6.451802   1000000.0
# 1 -8.827567 -6.534637  6.596879   1000000.0
# 2 -8.697445 -6.676893  6.728245   1000000.0
# 3 -8.538250 -6.729288  6.807171   1000000.0
# 4 -8.423157 -6.922978  6.960542   1000000.0

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data_inc['RHc'] = (-data_inc['V2'] + data_inc['V1'] - data_inc['V5'] + data_inc['V6'])/(data_inc['I']*data_inc['multiplier'])
data_inc['RHd'] = (-data_inc['V4'] + data_inc['V3'] - data_inc['V7'] + data_inc['V8'])/(data_inc['I']*data_inc['multiplier'])

data_inc['R'] = (data_inc['RHc'] + data_inc['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data_inc['B'],data_inc['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data_inc['B'],data_inc['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data_inc['B'],data_inc['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data_dec['B'], data_dec['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data_inc['B'],data_inc['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()

# %%
data = pd.concat([data_dec,data_inc])
data.reset_index(drop=True, inplace = True)
data.to_csv(f'{filename}')
