# %% [markdown]
# A304_SRO_NGO_Hall_150K_p1T_to_n1T

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\Users\\Admin\\Desktop\\Data\\9-june-2023\\A304_112K_P1T_N1T.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I            B           T          V1          V2          V3  \
# 0   0.001     0.302878  112.104004  548.233841 -548.108547 -530.388803
# 1   0.001   500.312431  112.003793  547.526226 -547.543918 -530.712151
# 2   0.001  1000.513809  111.999948  546.386416 -546.396280 -531.756339
# 3   0.001  1500.479272  111.999999  543.480477 -543.360785 -534.143170
# 4   0.001  2000.455420  112.000019  537.102254 -536.935498 -538.747343
# ..    ...          ...         ...         ...         ...         ...
# 69  0.001  1500.220532  112.000237  556.621613 -556.635903 -522.299265
# 70  0.001  2000.372083  112.000360  555.068030 -554.914640 -525.294202
# 71  0.001  2500.188977  112.000413  542.932583 -542.405401 -534.807897
# 72  0.001  3000.416479  112.000376  526.924893 -526.550256 -544.390921
# 73  0.001  3500.399048  112.000404  517.825053 -517.664762 -548.868598
#
#             V4     Rel_value  multiplier
# 0   530.301799  8.650000e-07     1000000
# 1   530.718992  7.666000e-07     1000000
# 2   531.807202  7.590000e-07     1000000
# 3   534.202512  7.273000e-07     1000000
# 4   538.832838  7.326000e-07     1000000
# ..         ...           ...         ...
# 69  522.343051  5.970000e-07     1000000
# 70  525.387613  6.017000e-07     1000000
# 71  535.004939  6.041000e-07     1000000
# 72  544.535432  6.078000e-07     1000000
# 73  548.956210  5.942000e-07     1000000
#
# [74 rows x 9 columns]

# %%
df['V1'] = -1*df['V1']
df['V2'] = -1*df['V2']
df['V3'] = -1*df['V3']
df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I            B  B_int           T          V1          V2          V3  \
# 0  0.001     0.302878      0  112.104004 -548.233841  548.108547  530.388803
# 1  0.001   500.312431    500  112.003793 -547.526226  547.543918  530.712151
# 2  0.001  1000.513809   1000  111.999948 -546.386416  546.396280  531.756339
# 3  0.001  1500.479272   1500  111.999999 -543.480477  543.360785  534.143170
# 4  0.001  2000.455420   2000  112.000019 -537.102254  536.935498  538.747343
#
#            V4     Rel_value  multiplier
# 0 -530.301799  8.650000e-07     1000000
# 1 -530.718992  7.666000e-07     1000000
# 2 -531.807202  7.590000e-07     1000000
# 3 -534.202512  7.273000e-07     1000000
# 4 -538.832838  7.326000e-07     1000000

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 49

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I            B  B_int           T          V1          V2          V3  \
# 0  0.001     0.302878      0  112.104004 -548.233841  548.108547  530.388803
# 1  0.001   500.312431    500  112.003793 -547.526226  547.543918  530.712151
# 2  0.001  1000.513809   1000  111.999948 -546.386416  546.396280  531.756339
# 3  0.001  1500.479272   1500  111.999999 -543.480477  543.360785  534.143170
# 4  0.001  2000.455420   2000  112.000019 -537.102254  536.935498  538.747343
#
#            V4     Rel_value  multiplier
# 0 -530.301799  8.650000e-07     1000000
# 1 -530.718992  7.666000e-07     1000000
# 2 -531.807202  7.590000e-07     1000000
# 3 -534.202512  7.273000e-07     1000000
# 4 -538.832838  7.326000e-07     1000000

# %%
df_inc.head()
# Out:
#         I             B  B_int           T          V1          V2  \
# 50  0.001 -10000.308398 -10000  112.000058 -546.594480  546.594541
# 51  0.001  -9000.563672  -9000  112.000434 -547.410486  547.418221
# 52  0.001  -8000.409302  -8000  112.000212 -548.222693  548.242619
# 53  0.001  -7000.332056  -7000  112.000242 -549.076643  549.067655
# 54  0.001  -6000.346484  -6000  112.000468 -549.902360  549.898173
#
#             V3          V4     Rel_value  multiplier
# 50  500.231868 -500.245530  6.161000e-07     1000000
# 51  502.118371 -502.150914  6.021000e-07     1000000
# 52  503.991391 -504.029513  6.070000e-07     1000000
# 53  505.849850 -505.913629  5.968000e-07     1000000
# 54  507.730413 -507.773033  6.092000e-07     1000000

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#        I     B           T          V1          V2          V3          V4  \
# 0  0.001     0  112.104004 -548.233841  548.108547  530.388803 -530.301799
# 1  0.001   500  112.003793 -547.526226  547.543918  530.712151 -530.718992
# 2  0.001  1000  111.999948 -546.386416  546.396280  531.756339 -531.807202
# 3  0.001  1500  111.999999 -543.480477  543.360785  534.143170 -534.202512
# 4  0.001  2000  112.000019 -537.102254  536.935498  538.747343 -538.832838
#
#            V5          V6          V7          V8  multiplier
# 0 -555.201898  555.199383  519.254539 -519.278904     1000000
# 1 -554.738224  554.745238  518.268016 -518.302543     1000000
# 2 -554.278923  554.289745  517.303839 -517.322593     1000000
# 3 -553.815255  553.833263  516.318109 -516.371497     1000000
# 4 -553.372382  553.381189  515.360711 -515.393945     1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (data['V2'] - data['V1'] + data['V5'] - data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (data['V4'] - data['V3'] + data['V7'] - data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001 -10000  112.000058 -546.594480  546.594541  500.231868 -500.245530
# 1  0.001  -9000  112.000434 -547.410486  547.418221  502.118371 -502.150914
# 2  0.001  -8000  112.000212 -548.222693  548.242619  503.991391 -504.029513
# 3  0.001  -7000  112.000242 -549.076643  549.067655  505.849850 -505.913629
# 4  0.001  -6000  112.000468 -549.902360  549.898173  507.730413 -507.773033
#
#            V5          V6          V7          V8  multiplier
# 0 -500.369742  500.385154  546.735478 -546.752923     1000000
# 1 -502.213695  502.234099  547.504969 -547.559677     1000000
# 2 -504.123787  504.131557  548.311488 -548.354633     1000000
# 3 -506.065974  506.063114  549.111800 -549.152040     1000000
# 4 -508.060334  508.053442  549.887377 -549.932558     1000000

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (data2['V2'] - data2['V1'] + data2['V5'] - data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (data2['V4'] - data2['V3'] + data2['V7'] - data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()
