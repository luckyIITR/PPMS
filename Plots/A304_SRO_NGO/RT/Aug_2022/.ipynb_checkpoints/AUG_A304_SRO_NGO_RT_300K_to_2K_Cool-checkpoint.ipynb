# %% [markdown]
# # For VDP with Temperature
# Use for VDP with temperature variation.
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %% [markdown]
# Date : 21 Aug 22

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename='C:\\Users\\Admin\\Desktop\\Analysis\\Data\\21_aug\\A304_SRO_NGO_RT_0T_300_2K_Cool.csv'
df = pd.read_csv(filename, names=["T_S", "T","B", "I", "V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8"])
df['multiplier'] = 1
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#        T_S           T         B       I        V1        V2        V3  \
# 0    300.0  300.048001  0.331451  0.0002 -0.001628  0.001591 -0.001885
# 1    298.0  297.959294  0.342880  0.0002 -0.001622  0.001586 -0.001879
# 2    296.0  295.954926  0.348595  0.0002 -0.001612  0.001580 -0.001868
# 3    294.0  293.951711  0.335533  0.0002 -0.001606  0.001574 -0.001862
# 4    292.0  291.948938  0.306960  0.0002 -0.001603  0.001567 -0.001858
# ..     ...         ...       ...     ...       ...       ...       ...
# 144   12.0   11.999285  0.351861  0.0002 -0.000334  0.000264 -0.000365
# 145   10.0    9.999656  0.334717  0.0002 -0.000327  0.000263 -0.000358
# 146    8.0    7.996027  0.348595  0.0002 -0.000323  0.000259 -0.000354
# 147    6.0    5.999952  0.368188  0.0002 -0.000322  0.000251 -0.000353
# 148    4.0    3.999332  0.384516  0.0002 -0.000318  0.000253 -0.000347
#
#            V4        V5        V6        V7        V8  multiplier
# 0    0.001844 -0.001625  0.001585 -0.001888  0.001847           1
# 1    0.001837 -0.001617  0.001579 -0.001882  0.001840           1
# 2    0.001830 -0.001608  0.001575 -0.001870  0.001834           1
# 3    0.001822 -0.001602  0.001568 -0.001863  0.001829           1
# 4    0.001816 -0.001597  0.001563 -0.001861  0.001820           1
# ..        ...       ...       ...       ...       ...         ...
# 144  0.000326 -0.000368  0.000232 -0.000427  0.000300           1
# 145  0.000321 -0.000356  0.000233 -0.000414  0.000299           1
# 146  0.000316 -0.000352  0.000229 -0.000411  0.000294           1
# 147  0.000312 -0.000357  0.000218 -0.000414  0.000285           1
# 148  0.000311 -0.000348  0.000222 -0.000405  0.000288           1
#
# [149 rows x 13 columns]

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])
df['R5'] = df['V5']/(df['multiplier']*df['I'])
df['R6'] = df['V6']/(df['multiplier']*df['I'])
df['R7'] = df['V7']/(df['multiplier']*df['I'])
df['R8'] = df['V8']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.plot(df['T'],df['R1'])
plt.title('R1 vs T')
plt.ylabel('R1')
plt.xlabel('T')
plt.subplot(2,4,2)
plt.plot(df['T'],df['R2'])
plt.title('R2 vs T')
plt.ylabel('R2')
plt.xlabel('T')
plt.subplot(2,4,3)
plt.plot(df['T'],df['R3'])
plt.title('R3 vs T')
plt.ylabel('R3')
plt.xlabel('T')
plt.subplot(2,4,4)
plt.plot(df['T'],df['R4'])
plt.title('R4 vs T')
plt.ylabel('R4')
plt.xlabel('T')
plt.subplot(2,4,5)
plt.plot(df['T'],df['R5'])
plt.title('R5 vs T')
plt.ylabel('R5')
plt.xlabel('T')
plt.subplot(2,4,6)
plt.plot(df['T'],df['R6'])
plt.title('R6 vs T')
plt.ylabel('R6')
plt.xlabel('T')
plt.subplot(2,4,7)
plt.plot(df['T'],df['R7'])
plt.title('R7 vs T')
plt.ylabel('R7')
plt.xlabel('T')
plt.subplot(2,4,8)
plt.plot(df['T'],df['R8'])
plt.title('R8 vs T')
plt.ylabel('R8')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.4, wspace = 0.6)
plt.show()

# %%
df['R12']=(df['V2']-df['V1'])/(df['multiplier']*df['I']*2)
df['R34']=(df['V4']-df['V3'])/(df['multiplier']*df['I']*2)
df['R56']=(df['V6']-df['V5'])/(df['multiplier']*df['I']*2)
df['R78']=(df['V8']-df['V7'])/(df['multiplier']*df['I']*2)

# %%
plt.figure(figsize=(17,13))
plt.subplot(2,2,1)
plt.plot(df['T'],df['R12'],'bo-')
plt.title('R12 vs T')
plt.ylabel('R12')
plt.xlabel('T')
plt.subplot(2,2,2)
plt.plot(df['T'],df['R34'],'bo-')
plt.title('R34 vs T')
plt.ylabel('R34')
plt.xlabel('T')
plt.subplot(2,2,3)
plt.plot(df['T'],df['R56'],'bo-')
plt.title('R56 vs T')
plt.ylabel('R56')
plt.xlabel('T')
plt.subplot(2,2,4)
plt.plot(df['T'],df['R78'],'bo-')
plt.title('R78 vs T')
plt.ylabel('R78')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R_a']=-1*(df['V1']-df['V2']+df['V5']-df['V6'])/(4*df['multiplier']*df['I'])
df['R_b']=-1*(df['V3']-df['V4']+df['V7']-df['V8'])/(4*df['multiplier']*df['I'])

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(df['T'],df['R_a'],'bo-')
plt.title('R_a vs T',fontsize=30)
plt.ylabel('R_a',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplot(1,2,2)
plt.plot(df['T'],df['R_b'],'bo-')
plt.title('R_b vs T',fontsize=30)
plt.ylabel('R_b',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df['T'],df['R_a'],'go-')
plt.ylabel('R',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.plot(df['T'],df['R_b'],'bo-')
plt.show()

# %%
df['R']=(df['R_a']+df['R_b'])/2

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],df['R'],'go-')
plt.title('R vs T',fontsize=30)
plt.ylabel('R',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.show()
