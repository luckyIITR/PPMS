# %% [markdown]
# # For VDP with Temperature
# Use for VDP with temperature variation.
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %% [markdown]
# Date : 21 Aug 22

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename='C:\\Users\\Admin\\Desktop\\Analysis\\Data\\21_aug\\A304_SRO_NGO_RT_1T_10K_300K_Warm.csv'
df = pd.read_csv(filename, names=["T_S", "T","B", "I", "V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8"])
df['multiplier'] = 1
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#        T_S           T             B       I        V1        V2        V3  \
# 0     10.0   10.000147  10000.145947  0.0002 -0.000317  0.000263 -0.000350
# 1     12.0   12.000379  10000.177051  0.0002 -0.000323  0.000268 -0.000355
# 2     14.0   14.000512  10000.213037  0.0002 -0.000322  0.000279 -0.000356
# 3     16.0   16.000248  10000.314160  0.0002 -0.000328  0.000286 -0.000365
# 4     18.0   18.000113  10000.368262  0.0002 -0.000339  0.000289 -0.000374
# ..     ...         ...           ...     ...       ...       ...       ...
# 140  290.0  290.050877  10000.282373  0.0002 -0.001590  0.001563 -0.001844
# 141  292.0  292.050307  10000.291992  0.0002 -0.001593  0.001571 -0.001847
# 142  294.0  294.049765  10000.288770  0.0002 -0.001600  0.001578 -0.001856
# 143  296.0  296.049817  10000.281396  0.0002 -0.001607  0.001582 -0.001863
# 144  298.0  298.049893  10000.287158  0.0002 -0.001616  0.001588 -0.001873
#
#            V4        V5        V6        V7        V8  multiplier
# 0    0.000318 -0.000341  0.000238 -0.000406  0.000296           1
# 1    0.000323 -0.000347  0.000244 -0.000409  0.000301           1
# 2    0.000332 -0.000340  0.000261 -0.000397  0.000316           1
# 3    0.000338 -0.000350  0.000265 -0.000415  0.000316           1
# 4    0.000346 -0.000354  0.000272 -0.000427  0.000324           1
# ..        ...       ...       ...       ...       ...         ...
# 140  0.001815 -0.001587  0.001556 -0.001850  0.001816           1
# 141  0.001822 -0.001591  0.001567 -0.001850  0.001825           1
# 142  0.001826 -0.001600  0.001570 -0.001858  0.001830           1
# 143  0.001832 -0.001605  0.001576 -0.001865  0.001836           1
# 144  0.001840 -0.001613  0.001581 -0.001877  0.001840           1
#
# [145 rows x 13 columns]

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])
df['R5'] = df['V5']/(df['multiplier']*df['I'])
df['R6'] = df['V6']/(df['multiplier']*df['I'])
df['R7'] = df['V7']/(df['multiplier']*df['I'])
df['R8'] = df['V8']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.plot(df['T'],df['R1'])
plt.title('R1 vs T')
plt.ylabel('R1')
plt.xlabel('T')
plt.subplot(2,4,2)
plt.plot(df['T'],df['R2'])
plt.title('R2 vs T')
plt.ylabel('R2')
plt.xlabel('T')
plt.subplot(2,4,3)
plt.plot(df['T'],df['R3'])
plt.title('R3 vs T')
plt.ylabel('R3')
plt.xlabel('T')
plt.subplot(2,4,4)
plt.plot(df['T'],df['R4'])
plt.title('R4 vs T')
plt.ylabel('R4')
plt.xlabel('T')
plt.subplot(2,4,5)
plt.plot(df['T'],df['R5'])
plt.title('R5 vs T')
plt.ylabel('R5')
plt.xlabel('T')
plt.subplot(2,4,6)
plt.plot(df['T'],df['R6'])
plt.title('R6 vs T')
plt.ylabel('R6')
plt.xlabel('T')
plt.subplot(2,4,7)
plt.plot(df['T'],df['R7'])
plt.title('R7 vs T')
plt.ylabel('R7')
plt.xlabel('T')
plt.subplot(2,4,8)
plt.plot(df['T'],df['R8'])
plt.title('R8 vs T')
plt.ylabel('R8')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.4, wspace = 0.6)
plt.show()

# %%
df['R12']=(df['V2']-df['V1'])/(df['multiplier']*df['I']*2)
df['R34']=(df['V4']-df['V3'])/(df['multiplier']*df['I']*2)
df['R56']=(df['V6']-df['V5'])/(df['multiplier']*df['I']*2)
df['R78']=(df['V8']-df['V7'])/(df['multiplier']*df['I']*2)

# %%
plt.figure(figsize=(17,13))
plt.subplot(2,2,1)
plt.plot(df['T'],df['R12'],'bo-')
plt.title('R12 vs T')
plt.ylabel('R12')
plt.xlabel('T')
plt.subplot(2,2,2)
plt.plot(df['T'],df['R34'],'bo-')
plt.title('R34 vs T')
plt.ylabel('R34')
plt.xlabel('T')
plt.subplot(2,2,3)
plt.plot(df['T'],df['R56'],'bo-')
plt.title('R56 vs T')
plt.ylabel('R56')
plt.xlabel('T')
plt.subplot(2,2,4)
plt.plot(df['T'],df['R78'],'bo-')
plt.title('R78 vs T')
plt.ylabel('R78')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R_a']=-1*(df['V1']-df['V2']+df['V5']-df['V6'])/(4*df['multiplier']*df['I'])
df['R_b']=-1*(df['V3']-df['V4']+df['V7']-df['V8'])/(4*df['multiplier']*df['I'])

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(df['T'],df['R_a'],'bo-')
plt.title('R_a vs T',fontsize=30)
plt.ylabel('R_a',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplot(1,2,2)
plt.plot(df['T'],df['R_b'],'bo-')
plt.title('R_b vs T',fontsize=30)
plt.ylabel('R_b',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df['T'],df['R_a'],'go-')
plt.ylabel('R',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.plot(df['T'],df['R_b'],'bo-')
plt.show()

# %%
df['R']=(df['R_a']+df['R_b'])/2

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],df['R'],'go-')
plt.title('R vs T',fontsize=30)
plt.ylabel('R',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.show()
