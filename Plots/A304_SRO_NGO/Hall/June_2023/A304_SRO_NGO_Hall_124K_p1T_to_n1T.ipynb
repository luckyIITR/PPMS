# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.209033  10000  124.103601  577.723977 -577.623861 -595.917161
# 1  0.001   9000.246240   9000  124.004527  576.621240 -576.570142 -595.352238
# 2  0.001   8000.332349   8000  124.000646  575.634673 -575.610613 -594.988112
# 3  0.001   7000.485645   7000  123.999910  574.689865 -574.684363 -594.630584
# 4  0.001   6000.510571   6000  123.999896  573.773860 -573.765179 -594.242798
#
#            V4     Rel_value  multiplier
# 0  595.844690  1.060200e-06     1000000
# 1  595.315822  9.177000e-07     1000000
# 2  594.948322  8.625000e-07     1000000
# 3  594.597698  8.312000e-07     1000000
# 4  594.212485  8.199000e-07     1000000

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 32

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.209033  10000  124.103601  577.723977 -577.623861 -595.917161
# 1  0.001   9000.246240   9000  124.004527  576.621240 -576.570142 -595.352238
# 2  0.001   8000.332349   8000  124.000646  575.634673 -575.610613 -594.988112
# 3  0.001   7000.485645   7000  123.999910  574.689865 -574.684363 -594.630584
# 4  0.001   6000.510571   6000  123.999896  573.773860 -573.765179 -594.242798
#
#            V4     Rel_value  multiplier
# 0  595.844690  1.060200e-06     1000000
# 1  595.315822  9.177000e-07     1000000
# 2  594.948322  8.625000e-07     1000000
# 3  594.597698  8.312000e-07     1000000
# 4  594.212485  8.199000e-07     1000000

# %%
df_inc.head()
# Out:
#         I             B  B_int           T          V1          V2  \
# 33  0.001 -10000.333008 -10000  124.000019  594.507392 -594.488083
# 34  0.001  -9000.402832  -9000  124.000103  594.184146 -594.195585
# 35  0.001  -8000.457324  -8000  124.000164  593.891073 -593.906401
# 36  0.001  -7000.607202  -7000  124.000329  593.579328 -593.576680
# 37  0.001  -6000.383179  -6000  124.000436  593.267014 -593.251897
#
#             V3          V4     Rel_value  multiplier
# 33 -576.524018  576.472160  7.187000e-07     1000000
# 34 -575.585206  575.547645  7.180000e-07     1000000
# 35 -574.682638  574.652567  7.298000e-07     1000000
# 36 -573.789241  573.726594  7.230000e-07     1000000
# 37 -572.883389  572.852650  7.179000e-07     1000000

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001  10000  124.103601  577.723977 -577.623861 -595.917161  595.844690
# 1  0.001   9000  124.004527  576.621240 -576.570142 -595.352238  595.315822
# 2  0.001   8000  124.000646  575.634673 -575.610613 -594.988112  594.948322
# 3  0.001   7000  123.999910  574.689865 -574.684363 -594.630584  594.597698
# 4  0.001   6000  123.999896  573.773860 -573.765179 -594.242798  594.212485
#
#            V5          V6          V7          V8  multiplier
# 0  594.507392 -594.488083 -576.524018  576.472160     1000000
# 1  594.184146 -594.195585 -575.585206  575.547645     1000000
# 2  593.891073 -593.906401 -574.682638  574.652567     1000000
# 3  593.579328 -593.576680 -573.789241  573.726594     1000000
# 4  593.267014 -593.251897 -572.883389  572.852650     1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (data['V2'] - data['V1'] + data['V5'] - data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (data['V4'] - data['V3'] + data['V7'] - data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001 -10000  124.000019  594.507392 -594.488083 -576.524018  576.472160
# 1  0.001  -9000  124.000103  594.184146 -594.195585 -575.585206  575.547645
# 2  0.001  -8000  124.000164  593.891073 -593.906401 -574.682638  574.652567
# 3  0.001  -7000  124.000329  593.579328 -593.576680 -573.789241  573.726594
# 4  0.001  -6000  124.000436  593.267014 -593.251897 -572.883389  572.852650
#
#            V5          V6          V7          V8  multiplier
# 0  577.723977 -577.623861 -595.917161  595.844690     1000000
# 1  576.621240 -576.570142 -595.352238  595.315822     1000000
# 2  575.634673 -575.610613 -594.988112  594.948322     1000000
# 3  574.689865 -574.684363 -594.630584  594.597698     1000000
# 4  573.773860 -573.765179 -594.242798  594.212485     1000000

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (data2['V2'] - data2['V1'] + data2['V5'] - data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (data2['V4'] - data2['V3'] + data2['V7'] - data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()

# %%
data.to_pickle("./pickle_data/123K_dec.pkl")
data2.to_pickle("./pickle_data/123K_inc.pkl")
