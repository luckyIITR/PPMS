# %% [markdown]
# # A304_SRO_NGO_Hall_121K_p1T_to_n1T

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\Users\\Admin\\Desktop\\Data\\21june2023\\A304_121K.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I             B           T          V1          V2          V3  \
# 0   0.001  10000.426172  120.997712 -134.183567  134.192642  137.470978
# 1   0.001   9000.265039  120.999192 -132.882062  132.870404  136.903938
# 2   0.001   8000.570752  121.000327 -131.567085  131.557276  136.349379
# 3   0.001   7000.477417  121.000607 -130.266011  130.250591  135.784192
# 4   0.001   6000.468018  121.000182 -128.979677  128.960732  135.188638
# ..    ...           ...         ...         ...         ...         ...
# 61  0.001   6000.217480  121.000310 -128.945065  128.934463  135.209054
# 62  0.001   7000.446289  121.000053 -130.290867  130.279040  135.767437
# 63  0.001   8000.322559  120.999839 -131.589458  131.580071  136.345820
# 64  0.001   9000.480762  120.999712 -132.888211  132.902081  136.873702
# 65  0.001  10000.455518  121.000498 -134.218200  134.215742  137.424257
#
#             V4     Rel_value  multiplier
# 0  -137.389416  7.168000e-07     1000000
# 1  -136.868495  7.292000e-07     1000000
# 2  -136.306570  7.206000e-07     1000000
# 3  -135.739533  7.337000e-07     1000000
# 4  -135.145221  7.376000e-07     1000000
# ..         ...           ...         ...
# 61 -135.161800  6.868000e-07     1000000
# 62 -135.722254  6.650000e-07     1000000
# 63 -136.280250  6.663000e-07     1000000
# 64 -136.845047  6.736000e-07     1000000
# 65 -137.371043  6.612000e-07     1000000
#
# [66 rows x 9 columns]

# %%
df['V1'] = -1*df['V1']
df['V2'] = -1*df['V2']
df['V3'] = -1*df['V3']
df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.426172  10000  120.997712  134.183567 -134.192642 -137.470978
# 1  0.001   9000.265039   9000  120.999192  132.882062 -132.870404 -136.903938
# 2  0.001   8000.570752   8000  121.000327  131.567085 -131.557276 -136.349379
# 3  0.001   7000.477417   7000  121.000607  130.266011 -130.250591 -135.784192
# 4  0.001   6000.468018   6000  121.000182  128.979677 -128.960732 -135.188638
#
#            V4     Rel_value  multiplier
# 0  137.389416  7.168000e-07     1000000
# 1  136.868495  7.292000e-07     1000000
# 2  136.306570  7.206000e-07     1000000
# 3  135.739533  7.337000e-07     1000000
# 4  135.145221  7.376000e-07     1000000

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 32

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.426172  10000  120.997712  134.183567 -134.192642 -137.470978
# 1  0.001   9000.265039   9000  120.999192  132.882062 -132.870404 -136.903938
# 2  0.001   8000.570752   8000  121.000327  131.567085 -131.557276 -136.349379
# 3  0.001   7000.477417   7000  121.000607  130.266011 -130.250591 -135.784192
# 4  0.001   6000.468018   6000  121.000182  128.979677 -128.960732 -135.188638
#
#            V4     Rel_value  multiplier
# 0  137.389416  7.168000e-07     1000000
# 1  136.868495  7.292000e-07     1000000
# 2  136.306570  7.206000e-07     1000000
# 3  135.739533  7.337000e-07     1000000
# 4  135.145221  7.376000e-07     1000000

# %%
df_inc.head()
# Out:
#         I             B  B_int           T          V1          V2  \
# 33  0.001 -10000.368311 -10000  121.000742  137.546441 -137.548353
# 34  0.001  -9000.604980  -9000  121.000052  136.991817 -136.973298
# 35  0.001  -8000.447559  -8000  121.000026  136.433388 -136.422852
# 36  0.001  -7000.353394  -7000  121.000412  135.854764 -135.849807
# 37  0.001  -6000.333398  -6000  121.000399  135.259781 -135.263006
#
#             V3          V4     Rel_value  multiplier
# 33 -134.297384  134.244725  7.151000e-07     1000000
# 34 -132.967708  132.942843  7.072000e-07     1000000
# 35 -131.672434  131.612356  7.025000e-07     1000000
# 36 -130.361268  130.311928  7.029000e-07     1000000
# 37 -129.033996  129.003795  6.964000e-07     1000000

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001  10000  120.997712  134.183567 -134.192642 -137.470978  137.389416
# 1  0.001   9000  120.999192  132.882062 -132.870404 -136.903938  136.868495
# 2  0.001   8000  121.000327  131.567085 -131.557276 -136.349379  136.306570
# 3  0.001   7000  121.000607  130.266011 -130.250591 -135.784192  135.739533
# 4  0.001   6000  121.000182  128.979677 -128.960732 -135.188638  135.145221
#
#            V5          V6          V7          V8  multiplier
# 0  137.546441 -137.548353 -134.297384  134.244725     1000000
# 1  136.991817 -136.973298 -132.967708  132.942843     1000000
# 2  136.433388 -136.422852 -131.672434  131.612356     1000000
# 3  135.854764 -135.849807 -130.361268  130.311928     1000000
# 4  135.259781 -135.263006 -129.033996  129.003795     1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (data['V2'] - data['V1'] + data['V5'] - data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (data['V4'] - data['V3'] + data['V7'] - data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001 -10000  121.000742  137.546441 -137.548353 -134.297384  134.244725
# 1  0.001  -9000  121.000052  136.991817 -136.973298 -132.967708  132.942843
# 2  0.001  -8000  121.000026  136.433388 -136.422852 -131.672434  131.612356
# 3  0.001  -7000  121.000412  135.854764 -135.849807 -130.361268  130.311928
# 4  0.001  -6000  121.000399  135.259781 -135.263006 -129.033996  129.003795
#
#            V5          V6          V7          V8  multiplier
# 0  134.183567 -134.192642 -137.470978  137.389416     1000000
# 1  132.882062 -132.870404 -136.903938  136.868495     1000000
# 2  131.567085 -131.557276 -136.349379  136.306570     1000000
# 3  130.266011 -130.250591 -135.784192  135.739533     1000000
# 4  128.979677 -128.960732 -135.188638  135.145221     1000000

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (data2['V2'] - data2['V1'] + data2['V5'] - data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (data2['V4'] - data2['V3'] + data2['V7'] - data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()
