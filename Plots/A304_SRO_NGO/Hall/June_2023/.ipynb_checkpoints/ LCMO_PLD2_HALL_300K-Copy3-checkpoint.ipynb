# %% [markdown]
#  LCMO_PLD2_HALL_300K

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\users\\Admin\\Desktop\\Analysis\\Plots\\LCMO_PLD2\\HALL\\LCMO_PLD2_150K_HALL_+5T_to_-5T.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value','multiplier'])

df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#             I             B           T            V1            V2  \
# 0    0.000001  49999.647266  149.943265  107271.75620 -156750.75336
# 1    0.000001  49000.365234  149.807124  108032.27122 -157506.76695
# 2    0.000001  48000.050391  149.770216  109037.16741 -158809.46445
# 3    0.000001  47000.595117  149.773612  109754.66994 -159596.79825
# 4    0.000001  46000.490430  149.789535  110648.72861 -160399.07651
# ..        ...           ...         ...           ...           ...
# 197  0.000001  46000.299609  149.999408  114671.52867 -160657.80620
# 198  0.000001  47000.435156  149.999868  113783.57631 -159679.82491
# 199  0.000001  48000.472656  149.998945  112876.54031 -158840.59236
# 200  0.000001  49000.425000  149.999068  111972.61152 -157741.84498
# 201  0.000001  50000.245703  149.999286  111171.67975 -156654.45355
#
#                V3            V4  Rel_value  multiplier
# 0   -126995.39915  142776.33971  -0.003811   1000000.0
# 1   -127616.95219  146104.13733  -0.003774   1000000.0
# 2   -128388.76961  148777.91150  -0.004032   1000000.0
# 3   -128646.11810  150003.50895  -0.004174   1000000.0
# 4   -128431.57117  150785.28588  -0.004181   1000000.0
# ..            ...           ...        ...         ...
# 197 -133812.80883  150961.35809  -0.004234   1000000.0
# 198 -133704.98476  149999.05112  -0.003942   1000000.0
# 199 -133340.65748  149031.66828  -0.003961   1000000.0
# 200 -132098.43254  147016.34115  -0.003941   1000000.0
# 201 -131139.22843  143495.45607  -0.003824   1000000.0
#
# [202 rows x 9 columns]

# %%
df['V1'] = -1*df['V1']
df['V2'] = -1*df['V2']
df['V3'] = -1*df['V3']
df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#           I             B  B_int           T            V1            V2  \
# 0  0.000001  49999.647266  50000  149.943265 -107271.75620  156750.75336
# 1  0.000001  49000.365234  49000  149.807124 -108032.27122  157506.76695
# 2  0.000001  48000.050391  48000  149.770216 -109037.16741  158809.46445
# 3  0.000001  47000.595117  47000  149.773612 -109754.66994  159596.79825
# 4  0.000001  46000.490430  46000  149.789535 -110648.72861  160399.07651
#
#              V3            V4  Rel_value  multiplier
# 0  126995.39915 -142776.33971  -0.003811   1000000.0
# 1  127616.95219 -146104.13733  -0.003774   1000000.0
# 2  128388.76961 -148777.91150  -0.004032   1000000.0
# 3  128646.11810 -150003.50895  -0.004174   1000000.0
# 4  128431.57117 -150785.28588  -0.004181   1000000.0

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 50000 -50000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 100

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#           I             B  B_int           T            V1            V2  \
# 0  0.000001  49999.647266  50000  149.943265 -107271.75620  156750.75336
# 1  0.000001  49000.365234  49000  149.807124 -108032.27122  157506.76695
# 2  0.000001  48000.050391  48000  149.770216 -109037.16741  158809.46445
# 3  0.000001  47000.595117  47000  149.773612 -109754.66994  159596.79825
# 4  0.000001  46000.490430  46000  149.789535 -110648.72861  160399.07651
#
#              V3            V4  Rel_value  multiplier
# 0  126995.39915 -142776.33971  -0.003811   1000000.0
# 1  127616.95219 -146104.13733  -0.003774   1000000.0
# 2  128388.76961 -148777.91150  -0.004032   1000000.0
# 3  128646.11810 -150003.50895  -0.004174   1000000.0
# 4  128431.57117 -150785.28588  -0.004181   1000000.0

# %%
df_inc.head()
# Out:
#             I             B  B_int           T            V1            V2  \
# 101  0.000001 -50000.615430 -50000  149.997459 -110434.24426  156668.05962
# 102  0.000001 -49000.493555 -49000  149.995986 -111168.29427  157663.18914
# 103  0.000001 -48000.591016 -48000  149.997627 -111985.61538  158634.14146
# 104  0.000001 -47000.604492 -47000  149.999207 -112871.09687  159642.91458
# 105  0.000001 -46000.240039 -46000  149.998082 -113745.79701  160694.56030
#
#                V3            V4  Rel_value  multiplier
# 101  130063.71652 -143625.31212  -0.003888   1000000.0
# 102  131137.74133 -146942.41290  -0.003891   1000000.0
# 103  132220.85719 -149095.36534  -0.004023   1000000.0
# 104  132744.61767 -149878.42310  -0.003881   1000000.0
# 105  132596.05953 -151027.12976  -0.004202   1000000.0

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#           I      B           T            V1            V2            V3  \
# 0  0.000001  50000  149.943265 -107271.75620  156750.75336  126995.39915
# 1  0.000001  49000  149.807124 -108032.27122  157506.76695  127616.95219
# 2  0.000001  48000  149.770216 -109037.16741  158809.46445  128388.76961
# 3  0.000001  47000  149.773612 -109754.66994  159596.79825  128646.11810
# 4  0.000001  46000  149.789535 -110648.72861  160399.07651  128431.57117
#
#              V4            V5            V6            V7            V8  \
# 0 -142776.33971 -110434.24426  156668.05962  130063.71652 -143625.31212
# 1 -146104.13733 -111168.29427  157663.18914  131137.74133 -146942.41290
# 2 -148777.91150 -111985.61538  158634.14146  132220.85719 -149095.36534
# 3 -150003.50895 -112871.09687  159642.91458  132744.61767 -149878.42310
# 4 -150785.28588 -113745.79701  160694.56030  132596.05953 -151027.12976
#
#    multiplier
# 0   1000000.0
# 1   1000000.0
# 2   1000000.0
# 3   1000000.0
# 4   1000000.0

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (-data['V2'] + data['V1'] - data['V5'] + data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (-data['V4'] + data['V3'] - data['V7'] + data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#           I      B           T            V1            V2            V3  \
# 0  0.000001 -50000  149.997459 -110434.24426  156668.05962  130063.71652
# 1  0.000001 -49000  149.995986 -111168.29427  157663.18914  131137.74133
# 2  0.000001 -48000  149.997627 -111985.61538  158634.14146  132220.85719
# 3  0.000001 -47000  149.999207 -112871.09687  159642.91458  132744.61767
# 4  0.000001 -46000  149.998082 -113745.79701  160694.56030  132596.05953
#
#              V4            V5            V6            V7            V8  \
# 0 -143625.31212 -107271.75620  156750.75336  126995.39915 -142776.33971
# 1 -146942.41290 -108032.27122  157506.76695  127616.95219 -146104.13733
# 2 -149095.36534 -109037.16741  158809.46445  128388.76961 -148777.91150
# 3 -149878.42310 -109754.66994  159596.79825  128646.11810 -150003.50895
# 4 -151027.12976 -110648.72861  160399.07651  128431.57117 -150785.28588
#
#    multiplier
# 0   1000000.0
# 1   1000000.0
# 2   1000000.0
# 3   1000000.0
# 4   1000000.0

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (-data2['V2'] + data2['V1'] - data2['V5'] + data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (-data2['V4'] + data2['V3'] - data2['V7'] + data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()
