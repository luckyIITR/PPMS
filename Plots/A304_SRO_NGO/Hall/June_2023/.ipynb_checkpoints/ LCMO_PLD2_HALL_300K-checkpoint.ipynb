# %% [markdown]
#  LCMO_PLD2_HALL_300K

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\users\\Admin\\Desktop\\Analysis\\Plots\\LCMO_PLD2\\HALL\\LCMO_PLD2_300K_HALL_+5T_to_-5T.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value','multiplier'])

df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#             I             B           T           V1          V2           V3  \
# 0    0.000001  49999.591602  299.992789 -2856.606484 -578.239995 -4418.212319
# 1    0.000001  49000.441797  299.996207 -2924.647609 -544.483501 -4482.832998
# 2    0.000001  48000.578516  299.996953 -2959.596901 -502.578228 -4587.749939
# 3    0.000001  47000.233789  299.996831 -2982.874338 -517.226867 -4563.801254
# 4    0.000001  46000.420898  299.999380 -3009.308688 -465.521122 -4466.771025
# ..        ...           ...         ...          ...         ...          ...
# 197  0.000001  46000.444141  299.995692 -4384.249948   76.023344 -4038.547396
# 198  0.000001  47000.380273  300.001225 -4350.615431   62.048812 -4026.647240
# 199  0.000001  48000.460938  300.000163 -4329.289943   96.849102 -4002.390486
# 200  0.000001  49000.496875  300.002769 -4331.413003   63.102004 -4012.692563
# 201  0.000001  50000.608008  300.003604 -4301.308130   72.289942 -4043.534626
#
#              V4  Rel_value  multiplier
# 0    170.663123  -0.000145   1000000.0
# 1     13.624638  -0.000117   1000000.0
# 2    -56.525524  -0.000129   1000000.0
# 3    -70.251639  -0.000136   1000000.0
# 4     67.137925  -0.000139   1000000.0
# ..          ...        ...         ...
# 197 -780.754561  -0.000146   1000000.0
# 198 -903.861617  -0.000100   1000000.0
# 199 -749.288276  -0.000137   1000000.0
# 200 -816.874914  -0.000139   1000000.0
# 201 -860.401648  -0.000144   1000000.0
#
# [202 rows x 9 columns]

# %%
# df['V1'] = -1*df['V1']
# df['V2'] = -1*df['V2']
# df['V3'] = -1*df['V3']
# df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#           I             B  B_int           T           V1          V2  \
# 0  0.000001  49999.591602  50000  299.992789 -2856.606484 -578.239995
# 1  0.000001  49000.441797  49000  299.996207 -2924.647609 -544.483501
# 2  0.000001  48000.578516  48000  299.996953 -2959.596901 -502.578228
# 3  0.000001  47000.233789  47000  299.996831 -2982.874338 -517.226867
# 4  0.000001  46000.420898  46000  299.999380 -3009.308688 -465.521122
#
#             V3          V4  Rel_value  multiplier
# 0 -4418.212319  170.663123  -0.000145   1000000.0
# 1 -4482.832998   13.624638  -0.000117   1000000.0
# 2 -4587.749939  -56.525524  -0.000129   1000000.0
# 3 -4563.801254  -70.251639  -0.000136   1000000.0
# 4 -4466.771025   67.137925  -0.000139   1000000.0

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 50000 -50000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 100

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#           I             B  B_int           T           V1          V2  \
# 0  0.000001  49999.591602  50000  299.992789 -2856.606484 -578.239995
# 1  0.000001  49000.441797  49000  299.996207 -2924.647609 -544.483501
# 2  0.000001  48000.578516  48000  299.996953 -2959.596901 -502.578228
# 3  0.000001  47000.233789  47000  299.996831 -2982.874338 -517.226867
# 4  0.000001  46000.420898  46000  299.999380 -3009.308688 -465.521122
#
#             V3          V4  Rel_value  multiplier
# 0 -4418.212319  170.663123  -0.000145   1000000.0
# 1 -4482.832998   13.624638  -0.000117   1000000.0
# 2 -4587.749939  -56.525524  -0.000129   1000000.0
# 3 -4563.801254  -70.251639  -0.000136   1000000.0
# 4 -4466.771025   67.137925  -0.000139   1000000.0

# %%
df_inc.head()
# Out:
#             I             B  B_int           T           V1         V2  \
# 101  0.000001 -50000.605859 -50000  300.000011 -4273.754413  34.589333
# 102  0.000001 -49000.286914 -49000  300.002499 -4304.308451  55.184591
# 103  0.000001 -48000.582031 -48000  300.001384 -4337.192731  65.161569
# 104  0.000001 -47000.624414 -47000  300.001524 -4327.371413  58.322244
# 105  0.000001 -46000.481445 -46000  299.999130 -4348.030935  54.494078
#
#               V3          V4  Rel_value  multiplier
# 101 -4323.064535 -325.003085  -0.000145   1000000.0
# 102 -4268.579488 -291.820344  -0.000145   1000000.0
# 103 -4270.548680 -308.589330  -0.000138   1000000.0
# 104 -4330.715046 -307.211636  -0.000146   1000000.0
# 105 -4362.466908 -375.585685  -0.000127   1000000.0

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#           I      B           T           V1          V2           V3  \
# 0  0.000001  50000  299.992789 -2856.606484 -578.239995 -4418.212319
# 1  0.000001  49000  299.996207 -2924.647609 -544.483501 -4482.832998
# 2  0.000001  48000  299.996953 -2959.596901 -502.578228 -4587.749939
# 3  0.000001  47000  299.996831 -2982.874338 -517.226867 -4563.801254
# 4  0.000001  46000  299.999380 -3009.308688 -465.521122 -4466.771025
#
#            V4           V5         V6           V7          V8  multiplier
# 0  170.663123 -4273.754413  34.589333 -4323.064535 -325.003085   1000000.0
# 1   13.624638 -4304.308451  55.184591 -4268.579488 -291.820344   1000000.0
# 2  -56.525524 -4337.192731  65.161569 -4270.548680 -308.589330   1000000.0
# 3  -70.251639 -4327.371413  58.322244 -4330.715046 -307.211636   1000000.0
# 4   67.137925 -4348.030935  54.494078 -4362.466908 -375.585685   1000000.0

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (-data['V2'] + data['V1'] - data['V5'] + data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (-data['V4'] + data['V3'] - data['V7'] + data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#           I      B           T           V1         V2           V3  \
# 0  0.000001 -50000  300.000011 -4273.754413  34.589333 -4323.064535
# 1  0.000001 -49000  300.002499 -4304.308451  55.184591 -4268.579488
# 2  0.000001 -48000  300.001384 -4337.192731  65.161569 -4270.548680
# 3  0.000001 -47000  300.001524 -4327.371413  58.322244 -4330.715046
# 4  0.000001 -46000  299.999130 -4348.030935  54.494078 -4362.466908
#
#            V4           V5          V6           V7          V8  multiplier
# 0 -325.003085 -2856.606484 -578.239995 -4418.212319  170.663123   1000000.0
# 1 -291.820344 -2924.647609 -544.483501 -4482.832998   13.624638   1000000.0
# 2 -308.589330 -2959.596901 -502.578228 -4587.749939  -56.525524   1000000.0
# 3 -307.211636 -2982.874338 -517.226867 -4563.801254  -70.251639   1000000.0
# 4 -375.585685 -3009.308688 -465.521122 -4466.771025   67.137925   1000000.0

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (-data2['V2'] + data2['V1'] - data2['V5'] + data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (-data2['V4'] + data2['V3'] - data2['V7'] + data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()
