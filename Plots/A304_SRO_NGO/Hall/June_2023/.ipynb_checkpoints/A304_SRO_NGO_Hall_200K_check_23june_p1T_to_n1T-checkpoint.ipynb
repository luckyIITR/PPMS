# %% [markdown]
# # A304_SRO_NGO_Hall_200K_p1T_to_n1T

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\Users\\Admin\\Desktop\\Data\\23june2023\\A304_200KCHECK.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I             B           T          V1          V2          V3  \
# 0   0.001      0.233485  200.099664 -860.500213  860.332990  860.282760
# 1   0.001   5000.257959  200.009223 -857.695271  857.626664  862.783505
# 2   0.001  10000.287988  200.002437 -855.135172  855.092258  865.298570
# 3   0.001  10000.261914  200.000169 -855.164124  855.154746  865.336139
# 4   0.001   5000.419653  200.000158 -857.746480  857.723199  862.800157
# 5   0.001     -0.041635  200.000600 -860.276186  860.270280  860.275086
# 6   0.001  -5000.436841  199.999818 -862.827506  862.809016  857.750529
# 7   0.001 -10000.370898  200.000708 -865.381311  865.365860  855.214633
# 8   0.001 -10000.378955  200.000620 -865.370183  865.376401  855.229489
# 9   0.001  -5000.247363  199.999940 -862.864206  862.837970  857.788304
# 10  0.001     -0.082455  200.000553 -860.306639  860.288150  860.361543
# 11  0.001   5000.349463  200.000624 -857.758731  857.747910  862.891836
# 12  0.001  10000.364355  199.999862 -855.231081  855.211796  865.413994
#
#             V4     Rel_value  multiplier
# 0  -860.256962  1.464500e-06     1000000
# 1  -862.761383  1.161900e-06     1000000
# 2  -865.271147  1.046900e-06     1000000
# 3  -865.279192  1.017700e-06     1000000
# 4  -862.768633  9.991000e-07     1000000
# 5  -860.195776  9.712000e-07     1000000
# 6  -857.711756  9.389000e-07     1000000
# 7  -855.176488  9.190000e-07     1000000
# 8  -855.183202  9.037000e-07     1000000
# 9  -857.728238  8.917000e-07     1000000
# 10 -860.308394  8.914000e-07     1000000
# 11 -862.839168  8.645000e-07     1000000
# 12 -865.369818  8.429000e-07     1000000

# %%
df['V1'] = -1*df['V1']
df['V2'] = -1*df['V2']
df['V3'] = -1*df['V3']
df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001      0.233485      0  200.099664  860.500213 -860.332990 -860.282760
# 1  0.001   5000.257959   5000  200.009223  857.695271 -857.626664 -862.783505
# 2  0.001  10000.287988  10000  200.002437  855.135172 -855.092258 -865.298570
# 3  0.001  10000.261914  10000  200.000169  855.164124 -855.154746 -865.336139
# 4  0.001   5000.419653   5000  200.000158  857.746480 -857.723199 -862.800157
#
#            V4     Rel_value  multiplier
# 0  860.256962  1.464500e-06     1000000
# 1  862.761383  1.161900e-06     1000000
# 2  865.271147  1.046900e-06     1000000
# 3  865.279192  1.017700e-06     1000000
# 4  862.768633  9.991000e-07     1000000

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ### Truncating intial data (0 to 1 T)

# %%
B_max = max(df['B_int'])
B_max_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_max:
        B_max_first_idx = i
        break
B_max_first_idx
# Out:
# 2

# %%
df = df.iloc[B_max_first_idx+1:].copy()
df.reset_index(inplace = True, drop = True) # resetting index

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 4

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.261914  10000  200.000169  855.164124 -855.154746 -865.336139
# 1  0.001   5000.419653   5000  200.000158  857.746480 -857.723199 -862.800157
# 2  0.001     -0.041635      0  200.000600  860.276186 -860.270280 -860.275086
# 3  0.001  -5000.436841  -5000  199.999818  862.827506 -862.809016 -857.750529
# 4  0.001 -10000.370898 -10000  200.000708  865.381311 -865.365860 -855.214633
#
#            V4     Rel_value  multiplier
# 0  865.279192  1.017700e-06     1000000
# 1  862.768633  9.991000e-07     1000000
# 2  860.195776  9.712000e-07     1000000
# 3  857.711756  9.389000e-07     1000000
# 4  855.176488  9.190000e-07     1000000

# %%
df_inc.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 5  0.001 -10000.378955 -10000  200.000620  865.370183 -865.376401 -855.229489
# 6  0.001  -5000.247363  -5000  199.999940  862.864206 -862.837970 -857.788304
# 7  0.001     -0.082455      0  200.000553  860.306639 -860.288150 -860.361543
# 8  0.001   5000.349463   5000  200.000624  857.758731 -857.747910 -862.891836
# 9  0.001  10000.364355  10000  199.999862  855.231081 -855.211796 -865.413994
#
#            V4     Rel_value  multiplier
# 5  855.183202  9.037000e-07     1000000
# 6  857.728238  8.917000e-07     1000000
# 7  860.308394  8.914000e-07     1000000
# 8  862.839168  8.645000e-07     1000000
# 9  865.369818  8.429000e-07     1000000

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001  10000  200.000169  855.164124 -855.154746 -865.336139  865.279192
# 1  0.001   5000  200.000158  857.746480 -857.723199 -862.800157  862.768633
# 2  0.001      0  200.000600  860.276186 -860.270280 -860.275086  860.195776
# 3  0.001  -5000  199.999818  862.827506 -862.809016 -857.750529  857.711756
# 4  0.001 -10000  200.000708  865.381311 -865.365860 -855.214633  855.176488
#
#            V5          V6          V7          V8  multiplier
# 0  865.370183 -865.376401 -855.229489  855.183202     1000000
# 1  862.864206 -862.837970 -857.788304  857.728238     1000000
# 2  860.306639 -860.288150 -860.361543  860.308394     1000000
# 3  857.758731 -857.747910 -862.891836  862.839168     1000000
# 4  855.231081 -855.211796 -865.413994  865.369818     1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (data['V2'] - data['V1'] + data['V5'] - data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (data['V4'] - data['V3'] + data['V7'] - data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001 -10000  200.000620  865.370183 -865.376401 -855.229489  855.183202
# 1  0.001  -5000  199.999940  862.864206 -862.837970 -857.788304  857.728238
# 2  0.001      0  200.000553  860.306639 -860.288150 -860.361543  860.308394
# 3  0.001   5000  200.000624  857.758731 -857.747910 -862.891836  862.839168
# 4  0.001  10000  199.999862  855.231081 -855.211796 -865.413994  865.369818
#
#            V5          V6          V7          V8  multiplier
# 0  855.164124 -855.154746 -865.336139  865.279192     1000000
# 1  857.746480 -857.723199 -862.800157  862.768633     1000000
# 2  860.276186 -860.270280 -860.275086  860.195776     1000000
# 3  862.827506 -862.809016 -857.750529  857.711756     1000000
# 4  865.381311 -865.365860 -855.214633  855.176488     1000000

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (data2['V2'] - data2['V1'] + data2['V5'] - data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (data2['V4'] - data2['V3'] + data2['V7'] - data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()

# %%
data.to_pickle("./pickle_data/120K_dec.pkl")
data2.to_pickle("./pickle_data/120K_inc.pkl")

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
x = data['B'].values.reshape((-1,1))
y = data['R'].values

# %%
model = LinearRegression(fit_intercept = True).fit(x, y)

# %%
r_sq = model.score(x, y)
print(f"coefficient of determination: {r_sq}")

print(f"intercept: {model.intercept_}")

print(f"slope: {model.coef_}")
# Out:
# coefficient of determination: 0.9999976688277011
# intercept: -3.3123827199994796e-05
# slope: [2.03338026e-06]

# %%
y_pred = model.predict(x)

# %% [markdown]
# # Hall Coefficient

# %%
slope = model.coef_ # ohm per gauss
thickness = 54*10**-5 # in cm

# %%
R_hall_coef =1/( 2.5*(10**7)*thickness*slope[0])

# %%
R_hall_coef #cm3/C
# Out:
# 36.42903182518114

# %% [markdown]
# # Density of Charge Carrier

# %%
n = 1/(R_hall_coef*1.602*10**-19)

# %%
n # per cubic cm
# Out:
# 1.7135226880002787e+17
