# %% [markdown]
# # A304_SRO_NGO_Hall_120K_CHECK_p1T_to_n1T

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\Users\\Admin\\Desktop\\Data\\21june2023\\A304_120K.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I             B           T          V1          V2          V3  \
# 0   0.001  10000.413037  119.999653 -135.787692  135.784539  134.191399
# 1   0.001   8000.285962  119.999415 -133.085907  133.063191  133.031774
# 2   0.001   6000.373389  119.999940 -130.396041  130.392144  131.833110
# 3   0.001   4000.214404  120.000116 -127.715945  127.668348  130.582734
# 4   0.001   2000.197382  119.999890 -125.027380  125.019172  129.249961
# 5   0.001      0.043268  119.999917 -122.474826  122.466072  127.635673
# 6   0.001  -2000.449713  119.999750 -130.757708  130.801033  119.579610
# 7   0.001  -4000.511511  119.999661 -130.841927  130.831331  127.357897
# 8   0.001  -6000.271436  119.999824 -131.893668  131.889478  130.389817
# 9   0.001  -8000.357813  120.000225 -133.016856  133.016254  133.137148
# 10  0.001 -10000.283887  119.999776 -134.124213  134.117248  135.838668
# 11  0.001 -10000.278271  120.000045 -134.111515  134.114531  135.820832
# 12  0.001  -8000.386279  120.000380 -132.993144  132.986142  133.126291
# 13  0.001  -6000.281177  120.000241 -131.830799  131.796816  130.439015
# 14  0.001  -4000.320508  120.000347 -130.592399  130.588171  127.749634
# 15  0.001  -2000.252039  120.000056 -129.253383  129.264663  125.064072
# 16  0.001     -0.160011  120.000358 -127.615524  127.621427  122.512389
# 17  0.001   1999.550793  120.000182 -119.240736  119.255373  130.965085
# 18  0.001   4000.588245  120.000534 -127.350184  127.322109  130.773014
# 19  0.001   6000.294238  120.000407 -130.393927  130.392095  131.815003
# 20  0.001   8000.365820  120.000254 -133.143459  133.137753  132.949625
# 21  0.001  10000.472070  119.999810 -135.830020  135.830190  134.054079
#
#             V4     Rel_value  multiplier
# 0  -134.155068  8.750000e-07     1000000
# 1  -132.992848  8.686000e-07     1000000
# 2  -131.793501  8.499000e-07     1000000
# 3  -130.544531  8.458000e-07     1000000
# 4  -129.200523  8.506000e-07     1000000
# 5  -127.589805  8.279000e-07     1000000
# 6  -119.552118  7.996000e-07     1000000
# 7  -127.334206  7.886000e-07     1000000
# 8  -130.347080  7.889000e-07     1000000
# 9  -133.091992  7.838000e-07     1000000
# 10 -135.779472  7.837000e-07     1000000
# 11 -135.787403  7.776000e-07     1000000
# 12 -133.083070  7.773000e-07     1000000
# 13 -130.391621  7.828000e-07     1000000
# 14 -127.722999  7.984000e-07     1000000
# 15 -125.020412  8.049000e-07     1000000
# 16 -122.469339  7.937000e-07     1000000
# 17 -130.945595  7.871000e-07     1000000
# 18 -130.733584  7.816000e-07     1000000
# 19 -131.785914  7.739000e-07     1000000
# 20 -132.896314  7.718000e-07     1000000
# 21 -134.002847  7.692000e-07     1000000

# %%
df['V1'] = -1*df['V1']
df['V2'] = -1*df['V2']
df['V3'] = -1*df['V3']
df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.413037  10000  119.999653  135.787692 -135.784539 -134.191399
# 1  0.001   8000.285962   8000  119.999415  133.085907 -133.063191 -133.031774
# 2  0.001   6000.373389   6000  119.999940  130.396041 -130.392144 -131.833110
# 3  0.001   4000.214404   4000  120.000116  127.715945 -127.668348 -130.582734
# 4  0.001   2000.197382   2000  119.999890  125.027380 -125.019172 -129.249961
#
#            V4     Rel_value  multiplier
# 0  134.155068  8.750000e-07     1000000
# 1  132.992848  8.686000e-07     1000000
# 2  131.793501  8.499000e-07     1000000
# 3  130.544531  8.458000e-07     1000000
# 4  129.200523  8.506000e-07     1000000

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 10

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.413037  10000  119.999653  135.787692 -135.784539 -134.191399
# 1  0.001   8000.285962   8000  119.999415  133.085907 -133.063191 -133.031774
# 2  0.001   6000.373389   6000  119.999940  130.396041 -130.392144 -131.833110
# 3  0.001   4000.214404   4000  120.000116  127.715945 -127.668348 -130.582734
# 4  0.001   2000.197382   2000  119.999890  125.027380 -125.019172 -129.249961
#
#            V4     Rel_value  multiplier
# 0  134.155068  8.750000e-07     1000000
# 1  132.992848  8.686000e-07     1000000
# 2  131.793501  8.499000e-07     1000000
# 3  130.544531  8.458000e-07     1000000
# 4  129.200523  8.506000e-07     1000000

# %%
df_inc.head()
# Out:
#         I             B  B_int           T          V1          V2  \
# 11  0.001 -10000.278271 -10000  120.000045  134.111515 -134.114531
# 12  0.001  -8000.386279  -8000  120.000380  132.993144 -132.986142
# 13  0.001  -6000.281177  -6000  120.000241  131.830799 -131.796816
# 14  0.001  -4000.320508  -4000  120.000347  130.592399 -130.588171
# 15  0.001  -2000.252039  -2000  120.000056  129.253383 -129.264663
#
#             V3          V4     Rel_value  multiplier
# 11 -135.820832  135.787403  7.776000e-07     1000000
# 12 -133.126291  133.083070  7.773000e-07     1000000
# 13 -130.439015  130.391621  7.828000e-07     1000000
# 14 -127.749634  127.722999  7.984000e-07     1000000
# 15 -125.064072  125.020412  8.049000e-07     1000000

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001  10000  119.999653  135.787692 -135.784539 -134.191399  134.155068
# 1  0.001   8000  119.999415  133.085907 -133.063191 -133.031774  132.992848
# 2  0.001   6000  119.999940  130.396041 -130.392144 -131.833110  131.793501
# 3  0.001   4000  120.000116  127.715945 -127.668348 -130.582734  130.544531
# 4  0.001   2000  119.999890  125.027380 -125.019172 -129.249961  129.200523
#
#            V5          V6          V7          V8  multiplier
# 0  134.111515 -134.114531 -135.820832  135.787403     1000000
# 1  132.993144 -132.986142 -133.126291  133.083070     1000000
# 2  131.830799 -131.796816 -130.439015  130.391621     1000000
# 3  130.592399 -130.588171 -127.749634  127.722999     1000000
# 4  129.253383 -129.264663 -125.064072  125.020412     1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (data['V2'] - data['V1'] + data['V5'] - data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (data['V4'] - data['V3'] + data['V7'] - data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001 -10000  120.000045  134.111515 -134.114531 -135.820832  135.787403
# 1  0.001  -8000  120.000380  132.993144 -132.986142 -133.126291  133.083070
# 2  0.001  -6000  120.000241  131.830799 -131.796816 -130.439015  130.391621
# 3  0.001  -4000  120.000347  130.592399 -130.588171 -127.749634  127.722999
# 4  0.001  -2000  120.000056  129.253383 -129.264663 -125.064072  125.020412
#
#            V5          V6          V7          V8  multiplier
# 0  135.787692 -135.784539 -134.191399  134.155068     1000000
# 1  133.085907 -133.063191 -133.031774  132.992848     1000000
# 2  130.396041 -130.392144 -131.833110  131.793501     1000000
# 3  127.715945 -127.668348 -130.582734  130.544531     1000000
# 4  125.027380 -125.019172 -129.249961  129.200523     1000000

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (data2['V2'] - data2['V1'] + data2['V5'] - data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (data2['V4'] - data2['V3'] + data2['V7'] - data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()
