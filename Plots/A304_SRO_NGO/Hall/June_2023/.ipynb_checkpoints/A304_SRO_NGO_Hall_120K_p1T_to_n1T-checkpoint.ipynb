# %% [markdown]
# # A304_SRO_NGO_Hall_120K_p1T_to_n1T

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\Users\\Admin\\Desktop\\Data\\13june2023\\A304_120K.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I             B           T          V1          V2          V3  \
# 0   0.001  10000.345361  119.999640  561.521047 -561.524305 -564.280505
# 1   0.001   9000.542432  120.000904  563.285859 -563.287451 -565.166574
# 2   0.001   8000.428003  120.000177  565.051794 -565.041614 -566.038997
# 3   0.001   7000.545190  120.000311  566.810465 -566.792349 -566.954291
# 4   0.001   6000.324438  119.999874  568.556184 -568.541927 -567.886105
# ..    ...           ...         ...         ...         ...         ...
# 61  0.001   6000.274707  120.000576  568.549922 -568.544865 -567.775620
# 62  0.001   7000.480664  120.000013  566.754820 -566.778509 -566.896443
# 63  0.001   8000.376465  120.000191  564.988308 -564.987339 -566.007265
# 64  0.001   9000.504248  120.000019  563.249061 -563.249337 -565.123745
# 65  0.001  10000.214014  119.999979  561.502196 -561.511132 -564.281684
#
#             V4     Rel_value  multiplier
# 0   564.325512  6.284000e-07     1000000
# 1   565.197758  6.154000e-07     1000000
# 2   566.079671  6.186000e-07     1000000
# 3   567.006535  6.126000e-07     1000000
# 4   567.932740  6.119000e-07     1000000
# ..         ...           ...         ...
# 61  567.806976  6.030000e-07     1000000
# 62  566.934119  6.033000e-07     1000000
# 63  566.052377  6.032000e-07     1000000
# 64  565.173492  6.040000e-07     1000000
# 65  564.323937  5.940000e-07     1000000
#
# [66 rows x 9 columns]

# %%
df['V1'] = -1*df['V1']
df['V2'] = -1*df['V2']
df['V3'] = -1*df['V3']
df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.345361  10000  119.999640 -561.521047  561.524305  564.280505
# 1  0.001   9000.542432   9000  120.000904 -563.285859  563.287451  565.166574
# 2  0.001   8000.428003   8000  120.000177 -565.051794  565.041614  566.038997
# 3  0.001   7000.545190   7000  120.000311 -566.810465  566.792349  566.954291
# 4  0.001   6000.324438   6000  119.999874 -568.556184  568.541927  567.886105
#
#            V4     Rel_value  multiplier
# 0 -564.325512  6.284000e-07     1000000
# 1 -565.197758  6.154000e-07     1000000
# 2 -566.079671  6.186000e-07     1000000
# 3 -567.006535  6.126000e-07     1000000
# 4 -567.932740  6.119000e-07     1000000

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 32

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.345361  10000  119.999640 -561.521047  561.524305  564.280505
# 1  0.001   9000.542432   9000  120.000904 -563.285859  563.287451  565.166574
# 2  0.001   8000.428003   8000  120.000177 -565.051794  565.041614  566.038997
# 3  0.001   7000.545190   7000  120.000311 -566.810465  566.792349  566.954291
# 4  0.001   6000.324438   6000  119.999874 -568.556184  568.541927  567.886105
#
#            V4     Rel_value  multiplier
# 0 -564.325512  6.284000e-07     1000000
# 1 -565.197758  6.154000e-07     1000000
# 2 -566.079671  6.186000e-07     1000000
# 3 -567.006535  6.126000e-07     1000000
# 4 -567.932740  6.119000e-07     1000000

# %%
df_inc.head()
# Out:
#         I             B  B_int           T          V1          V2  \
# 33  0.001 -10000.425977 -10000  120.000427 -564.231482  564.252937
# 34  0.001  -9000.442773  -9000  120.000185 -565.147696  565.159352
# 35  0.001  -8000.291650  -8000  120.000183 -566.016200  566.032850
# 36  0.001  -7000.418604  -7000  120.000341 -566.951091  566.942169
# 37  0.001  -6000.415088  -6000  120.000204 -567.848520  567.834368
#
#             V3          V4     Rel_value  multiplier
# 33  561.507771 -561.539045  5.811000e-07     1000000
# 34  563.279126 -563.298571  5.904000e-07     1000000
# 35  565.029792 -565.066410  5.905000e-07     1000000
# 36  566.782912 -566.816604  5.804000e-07     1000000
# 37  568.537584 -568.572857  5.882000e-07     1000000

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001  10000  119.999640 -561.521047  561.524305  564.280505 -564.325512
# 1  0.001   9000  120.000904 -563.285859  563.287451  565.166574 -565.197758
# 2  0.001   8000  120.000177 -565.051794  565.041614  566.038997 -566.079671
# 3  0.001   7000  120.000311 -566.810465  566.792349  566.954291 -567.006535
# 4  0.001   6000  119.999874 -568.556184  568.541927  567.886105 -567.932740
#
#            V5          V6          V7          V8  multiplier
# 0 -564.231482  564.252937  561.507771 -561.539045     1000000
# 1 -565.147696  565.159352  563.279126 -563.298571     1000000
# 2 -566.016200  566.032850  565.029792 -565.066410     1000000
# 3 -566.951091  566.942169  566.782912 -566.816604     1000000
# 4 -567.848520  567.834368  568.537584 -568.572857     1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (data['V2'] - data['V1'] + data['V5'] - data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (data['V4'] - data['V3'] + data['V7'] - data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#        I      B           T          V1          V2          V3          V4  \
# 0  0.001 -10000  120.000427 -564.231482  564.252937  561.507771 -561.539045
# 1  0.001  -9000  120.000185 -565.147696  565.159352  563.279126 -563.298571
# 2  0.001  -8000  120.000183 -566.016200  566.032850  565.029792 -565.066410
# 3  0.001  -7000  120.000341 -566.951091  566.942169  566.782912 -566.816604
# 4  0.001  -6000  120.000204 -567.848520  567.834368  568.537584 -568.572857
#
#            V5          V6          V7          V8  multiplier
# 0 -561.521047  561.524305  564.280505 -564.325512     1000000
# 1 -563.285859  563.287451  565.166574 -565.197758     1000000
# 2 -565.051794  565.041614  566.038997 -566.079671     1000000
# 3 -566.810465  566.792349  566.954291 -567.006535     1000000
# 4 -568.556184  568.541927  567.886105 -567.932740     1000000

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (data2['V2'] - data2['V1'] + data2['V5'] - data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (data2['V4'] - data2['V3'] + data2['V7'] - data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()
