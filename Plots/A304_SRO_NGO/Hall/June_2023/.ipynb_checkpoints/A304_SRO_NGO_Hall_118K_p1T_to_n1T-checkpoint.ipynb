# %% [markdown]
# # A304_SRO_NGO_Hall_118K_p1T_to_n1T

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
filename='C:\\Users\\Admin\\Desktop\\Data\\9_june_2023\\A304_SRO_NGO_Hall_118K_p1T_to_n1T.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I             B           T          V1          V2          V3  \
# 0   0.001  10000.442285  118.001784  546.130185 -546.131169 -559.699236
# 1   0.001   9000.501855  117.999740  547.876488 -547.873776 -560.522053
# 2   0.001   8000.342334  117.999963  549.648834 -549.662998 -561.410439
# 3   0.001   7000.446338  117.999766  551.435197 -551.438053 -562.263675
# 4   0.001   6000.437061  117.999395  553.206545 -553.221960 -563.161996
# ..    ...           ...         ...         ...         ...         ...
# 61  0.001   6000.169189  118.000214  553.205306 -553.207718 -562.981138
# 62  0.001   7000.376196  118.000071  551.334562 -551.358611 -562.130789
# 63  0.001   8000.488403  118.000426  549.538207 -549.529956 -561.295764
# 64  0.001   9000.424756  118.000368  547.734251 -547.741743 -560.444387
# 65  0.001  10000.392090  117.999903  545.949638 -545.948678 -559.606108
#
#             V4     Rel_value  multiplier
# 0   559.697809  6.798000e-07     1000000
# 1   560.551972  6.382000e-07     1000000
# 2   561.429207  6.127000e-07     1000000
# 3   562.296098  6.074000e-07     1000000
# 4   563.195325  6.030000e-07     1000000
# ..         ...           ...         ...
# 61  563.027299  5.295000e-07     1000000
# 62  562.174979  5.231000e-07     1000000
# 63  561.320237  5.375000e-07     1000000
# 64  560.482440  5.424000e-07     1000000
# 65  559.639003  5.513000e-07     1000000
#
# [66 rows x 9 columns]

# %%
df['V1'] = -1*df['V1']
df['V2'] = -1*df['V2']
df['V3'] = -1*df['V3']
df['V4'] = -1*df['V4']

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B', 'B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T          V1          V2          V3  \
# 0  0.001  10000.442285  10000  118.001784 -546.130185  546.131169  559.699236
# 1  0.001   9000.501855   9000  117.999740 -547.876488  547.873776  560.522053
# 2  0.001   8000.342334   8000  117.999963 -549.648834  549.662998  561.410439
# 3  0.001   7000.446338   7000  117.999766 -551.435197  551.438053  562.263675
# 4  0.001   6000.437061   6000  117.999395 -553.206545  553.221960  563.161996
#
#            V4     Rel_value  multiplier
# 0 -559.697809  6.798000e-07     1000000
# 1 -560.551972  6.382000e-07     1000000
# 2 -561.429207  6.127000e-07     1000000
# 3 -562.296098  6.074000e-07     1000000
# 4 -563.195325  6.030000e-07     1000000

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ### Truncating intial data (0 to 1 T)

# %%
B_max = max(df['B_int'])
B_max_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_max:
        B_max_first_idx = i
        break
B_max_first_idx
# Out:
# 0

# %%
df = df.iloc[B_max_first_idx+1:].copy()
df.reset_index(inplace = True, drop = True) # resetting index

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 31

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I            B  B_int           T          V1          V2          V3  \
# 0  0.001  9000.501855   9000  117.999740 -547.876488  547.873776  560.522053
# 1  0.001  8000.342334   8000  117.999963 -549.648834  549.662998  561.410439
# 2  0.001  7000.446338   7000  117.999766 -551.435197  551.438053  562.263675
# 3  0.001  6000.437061   6000  117.999395 -553.206545  553.221960  563.161996
# 4  0.001  5000.404907   5000  118.000325 -555.019564  555.011182  564.055558
#
#            V4     Rel_value  multiplier
# 0 -560.551972  6.382000e-07     1000000
# 1 -561.429207  6.127000e-07     1000000
# 2 -562.296098  6.074000e-07     1000000
# 3 -563.195325  6.030000e-07     1000000
# 4 -564.090087  5.928000e-07     1000000

# %%
df_inc.head()
# Out:
#         I             B  B_int           T          V1          V2  \
# 32  0.001 -10000.317334 -10000  117.999936 -559.526998  559.539579
# 33  0.001  -9000.382568  -9000  118.000124 -560.392226  560.403530
# 34  0.001  -8000.218115  -8000  118.000074 -561.260003  561.257071
# 35  0.001  -7000.559082  -7000  118.000272 -562.136388  562.136919
# 36  0.001  -6000.361182  -6000  118.000087 -563.025034  563.040345
#
#             V3          V4     Rel_value  multiplier
# 32  545.959023 -545.996003  5.627000e-07     1000000
# 33  547.782152 -547.810156  5.569000e-07     1000000
# 34  549.558890 -549.579248  5.552000e-07     1000000
# 35  551.364152 -551.405285  5.577000e-07     1000000
# 36  553.144038 -553.180678  5.493000e-07     1000000

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data = data[data['B_int_x'] == -1*data['B_int_y']] # selecting 
data = data[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data.reset_index(inplace = True, drop = True) # resetting index
data.head()
# Out:
#        I     B           T          V1          V2          V3          V4  \
# 0  0.001  9000  117.999740 -547.876488  547.873776  560.522053 -560.551972
# 1  0.001  8000  117.999963 -549.648834  549.662998  561.410439 -561.429207
# 2  0.001  7000  117.999766 -551.435197  551.438053  562.263675 -562.296098
# 3  0.001  6000  117.999395 -553.206545  553.221960  563.161996 -563.195325
# 4  0.001  5000  118.000325 -555.019564  555.011182  564.055558 -564.090087
#
#            V5          V6          V7          V8  multiplier
# 0 -560.392226  560.403530  547.782152 -547.810156     1000000
# 1 -561.260003  561.257071  549.558890 -549.579248     1000000
# 2 -562.136388  562.136919  551.364152 -551.405285     1000000
# 3 -563.025034  563.040345  553.144038 -553.180678     1000000
# 4 -563.942603  563.947769  554.968427 -554.988987     1000000

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data['RHc'] = (data['V2'] - data['V1'] + data['V5'] - data['V6'])/(data['I']*data['multiplier'])
data['RHd'] = (data['V4'] - data['V3'] + data['V7'] - data['V8'])/(data['I']*data['multiplier'])
data['R'] = (data['RHc'] + data['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data['B'],data['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data['B'],data['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'],data['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data2 = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data2 = data2[data2['B_int_x'] == -1*data2['B_int_y']] # selecting 
data2 = data2[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data2.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data2.reset_index(inplace = True, drop = True) # resetting index
data2.head()
# Out:
#        I     B           T          V1          V2          V3          V4  \
# 0  0.001 -9000  118.000124 -560.392226  560.403530  547.782152 -547.810156
# 1  0.001 -8000  118.000074 -561.260003  561.257071  549.558890 -549.579248
# 2  0.001 -7000  118.000272 -562.136388  562.136919  551.364152 -551.405285
# 3  0.001 -6000  118.000087 -563.025034  563.040345  553.144038 -553.180678
# 4  0.001 -5000  118.000262 -563.942603  563.947769  554.968427 -554.988987
#
#            V5          V6          V7          V8  multiplier
# 0 -547.876488  547.873776  560.522053 -560.551972     1000000
# 1 -549.648834  549.662998  561.410439 -561.429207     1000000
# 2 -551.435197  551.438053  562.263675 -562.296098     1000000
# 3 -553.206545  553.221960  563.161996 -563.195325     1000000
# 4 -555.019564  555.011182  564.055558 -564.090087     1000000

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data2['RHc'] = (data2['V2'] - data2['V1'] + data2['V5'] - data2['V6'])/(data2['I']*data2['multiplier'])
data2['RHd'] = (data2['V4'] - data2['V3'] + data2['V7'] - data2['V8'])/(data2['I']*data2['multiplier'])

data2['R'] = (data2['RHc'] + data2['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data2['B'],data2['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data2['B'],data2['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data2['B'],data2['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()
