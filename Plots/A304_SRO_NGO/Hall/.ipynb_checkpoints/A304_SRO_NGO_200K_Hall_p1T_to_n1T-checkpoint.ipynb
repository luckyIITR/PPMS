# %% [markdown]
# # For hall effect
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename='C:\\Users\\Admin\\Desktop\\Analysis\\Data\\9_march_2023\\A304_SRO_NGO_200K_Hall_p1T_to_n1T.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I             B           T          V1          V2          V3  \
# 0   0.001  10000.323145  200.011012 -794.605458  794.710435  784.212354
# 1   0.001   9000.424023  200.006441 -794.301692  794.368151  784.943313
# 2   0.001   8000.262207  200.000676 -793.885482  793.930469  785.567822
# 3   0.001   7000.414502  200.000105 -793.422453  793.481164  786.185842
# 4   0.001   6000.468066  200.000896 -792.971561  792.985970  786.749419
# ..    ...           ...         ...         ...         ...         ...
# 61  0.001   6000.278809  200.000378 -793.482702  793.522008  787.236413
# 62  0.001   7000.454541  200.000251 -794.000051  794.019134  786.692580
# 63  0.001   8000.334912  200.000769 -794.507021  794.516103  786.117022
# 64  0.001   9000.461621  200.000266 -794.974437  795.005637  785.575332
# 65  0.001  10000.356104  200.000633 -795.477051  795.525465  785.021034
#
#             V4     Rel_value  multiplier
# 0  -784.172912  5.578000e-07     1000000
# 1  -784.868408  5.303000e-07     1000000
# 2  -785.489586  5.254000e-07     1000000
# 3  -786.090047  5.219000e-07     1000000
# 4  -786.672301  5.330000e-07     1000000
# ..         ...           ...         ...
# 61 -787.155725  5.299000e-07     1000000
# 62 -786.606672  5.393000e-07     1000000
# 63 -786.007885  5.217000e-07     1000000
# 64 -785.482638  5.501000e-07     1000000
# 65 -784.930607  5.631000e-07     1000000
#
# [66 rows x 9 columns]

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(df['B'],df['R1'])
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(df['B'],df['R2'])
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(df['B'],df['R3'])
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(df['B'],df['R4'])
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R12']=(df['V2']-df['V1'])/(df['multiplier']*df['I']*2)
df['R34']=(df['V4']-df['V3'])/(df['multiplier']*df['I']*2)

# %%
plt.figure(figsize=(20,9))
plt.subplot(1,2,1)
plt.plot(df['B'],df['R12'],'bo-')
plt.title('R12 vs B')
plt.ylabel('R12')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(df['B'],df['R34'],'bo-')
plt.title('R34 vs B')
plt.ylabel('R34')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(12,12))
df['R'] = (df['R12']+df['R34'])/2
plt.plot(df['B'],df['R'],'go-')
plt.xlabel('B (Oe)',fontsize=15)
plt.ylabel('R_avg (Ohms)',fontsize=15)
plt.title('R_avg vs B (Oe)',fontsize=30)
plt.show()
