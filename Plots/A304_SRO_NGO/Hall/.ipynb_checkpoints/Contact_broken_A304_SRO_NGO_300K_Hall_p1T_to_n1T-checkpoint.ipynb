# %% [markdown]
# # For hall effect
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %% [markdown]
# # Contact broken

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename='C:\\Users\\Admin\\Desktop\\Analysis\\Data\\9_march_2023\\Contact_broken_A304_SRO_NGO_300K_Hall_p1T_to_n1T.csv'
df = pd.read_csv(filename, names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value'])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#         I             B           T          V1          V2          V3  \
# 0   0.001  10000.107031  299.983850 -934.088742  934.425352  931.949896
# 1   0.001   9000.446973  300.010054 -934.051900  934.120748  931.936776
# 2   0.001   8000.527490  300.003593 -933.986092  933.996483  931.850187
# 3   0.001   7000.429224  300.002431 -933.668456  933.734289  932.047390
# 4   0.001   6000.455005  300.000322 -933.639594  933.640546  932.185338
# 5   0.001   5000.378857  300.001126 -933.462617  933.556253  932.326258
# 6   0.001   4000.140979  300.001314 -933.359874  933.390666  932.482408
# 7   0.001   3000.400989  300.001205 -933.251723  933.216610  932.585407
# 8   0.001   2000.187585  300.000978 -933.079258  933.038197  932.619130
# 9   0.001   1000.227298  300.000853 -932.899080  932.927486  932.792554
# 10  0.001      0.040819  300.001683 -932.718028  932.745659  932.874647
# 11  0.001  -1000.601202  300.000862 -932.581754  932.608976  932.976967
# 12  0.001  -2000.216956  300.001282 -932.446853  932.435025  933.073186
# 13  0.001  -3000.608325  300.000697 -932.226296  932.261603  933.156581
# 14  0.001  -4000.252783  300.001549 -932.100823  932.106294  933.233099
# 15  0.001  -5000.251367  300.001112 -931.955088  932.033882  933.448189
# 16  0.001  -6000.214966  300.000540 -931.880423  931.887544  933.591805
# 17  0.001  -7000.214551  299.999548 -931.786244  931.765757  933.741489
# 18  0.001  -8000.353711  300.000847 -931.623689  931.646684  933.863858
# 19  0.001  -9000.242090  300.000945 -931.467014  931.525556  933.965751
# 20  0.001 -10000.416992  300.000677 -931.363741  931.376942  934.062805
# 21  0.001 -10000.423437  300.000665 -931.310368  931.311465  934.055268
# 22  0.001  -9000.467432  299.999120 -931.476596  931.512062  933.960342
# 23  0.001  -8000.377441  300.001051 -931.644532  931.639242  933.870070
# 24  0.001  -7000.452002  300.001741 -931.799222  931.774385  933.699988
# 25  0.001  -6000.479639  300.001314 -931.934431  931.960160  933.616094
# 26  0.001  -5000.317554  300.000107 -932.093978  932.139919  933.568437
# 27  0.001  -4000.313977  300.001038 -932.241681  932.279261  933.446232
# 28  0.001  -3000.465491  300.001027 -932.393033  932.396166  933.297967
# 29  0.001  -2000.233270  300.001471 -932.572099  932.606966  933.234986
# 30  0.001  -1000.581604  300.001387 -932.731957  932.818343  933.160818
# 31  0.001     -0.120825  300.000539 -932.973386  932.991967  933.091682
# 32  0.001   1000.502380  300.000508 -933.149398  933.155966  933.011724
# 33  0.001   2000.417883  300.000824 -933.317532  933.303381  932.844426
# 34  0.001   3000.447510  300.001131 -933.344583  933.376318  932.710231
# 35  0.001   4000.449463  300.000461 -933.511912  933.523969  932.590653
# 36  0.001   5000.265283  300.000449 -933.752970  933.766898  932.552996
# 37  0.001   6000.168408  300.000685 -933.900544  933.952236  932.489714
# 38  0.001   7000.589185  300.001089 -934.056758  933.999780  932.251249
# 39  0.001   8000.263745  300.000310 -934.112905  934.162701  932.149971
# 40  0.001   9000.391406  300.000899 -934.276445  934.287328  932.009855
# 41  0.001  10000.448926  300.000607 -934.352868  934.387873  931.835069
#
#             V4     Rel_value  multiplier
# 0  -931.725174  6.867000e-07     1000000
# 1  -931.855140  6.326000e-07     1000000
# 2  -931.677112  6.092000e-07     1000000
# 3  -931.941058  5.944000e-07     1000000
# 4  -932.125989  6.010000e-07     1000000
# 5  -932.269055  6.016000e-07     1000000
# 6  -932.392387  5.985000e-07     1000000
# 7  -932.458372  5.957000e-07     1000000
# 8  -932.522041  6.058000e-07     1000000
# 9  -932.697469  6.014000e-07     1000000
# 10 -932.839331  5.934000e-07     1000000
# 11 -932.910330  5.863000e-07     1000000
# 12 -932.979721  6.025000e-07     1000000
# 13 -933.049181  5.975000e-07     1000000
# 14 -933.152905  5.920000e-07     1000000
# 15 -933.313915  5.917000e-07     1000000
# 16 -933.522770  5.946000e-07     1000000
# 17 -933.658587  6.036000e-07     1000000
# 18 -933.736801  5.946000e-07     1000000
# 19 -933.885832  5.923000e-07     1000000
# 20 -933.989800  5.953000e-07     1000000
# 21 -933.999830  5.991000e-07     1000000
# 22 -933.877913  5.963000e-07     1000000
# 23 -933.750492  6.005000e-07     1000000
# 24 -933.626486  5.869000e-07     1000000
# 25 -933.537176  5.941000e-07     1000000
# 26 -933.453608  6.001000e-07     1000000
# 27 -933.360467  5.926000e-07     1000000
# 28 -933.270625  5.973000e-07     1000000
# 29 -933.162703  6.008000e-07     1000000
# 30 -933.061227  6.086000e-07     1000000
# 31 -933.072633  6.024000e-07     1000000
# 32 -932.900133  6.048000e-07     1000000
# 33 -932.751857  6.024000e-07     1000000
# 34 -932.608915  5.983000e-07     1000000
# 35 -932.516581  6.065000e-07     1000000
# 36 -932.548847  6.097000e-07     1000000
# 37 -932.415208  5.949000e-07     1000000
# 38 -932.125661  5.818000e-07     1000000
# 39 -932.029854  5.888000e-07     1000000
# 40 -931.902644  5.993000e-07     1000000
# 41 -931.769644  5.904000e-07     1000000

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
plt.plot(df['B'],df['R1'])
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(df['B'],df['R2'])
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(df['B'],df['R3'])
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(df['B'],df['R4'])
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R12']=(df['V2']-df['V1'])/(df['multiplier']*df['I']*2)
df['R34']=(df['V4']-df['V3'])/(df['multiplier']*df['I']*2)

# %%
plt.figure(figsize=(18,8))
plt.subplot(1,2,1)
plt.plot(df['B'],df['R12'],'bo-')
plt.title('R12 vs B')
plt.ylabel('R12')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(df['B'],df['R34'],'bo-')
plt.title('R34 vs B')
plt.ylabel('R34')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(6,6))
df['R'] = (df['R12']+df['R34'])/2
plt.plot(df['B'],df['R'],'go-')
plt.xlabel('B (Oe)',fontsize=15)
plt.ylabel('R_avg (Ohms)',fontsize=15)
plt.title('R_avg vs B (Oe)',fontsize=30)
plt.savefig('A304_100K.jpg')
plt.show()
