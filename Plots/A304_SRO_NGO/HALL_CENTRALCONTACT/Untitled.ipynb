# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Processed_data/A304_SRO_NGO_300K.csv")

# %%
df
# Out:
#     Unnamed: 0      I      B           T        V1        V2        V3  \
# 0            0  0.001  10000  300.000826  8.943632 -8.926101 -6.370625
# 1            1  0.001   9000  300.000426  8.853747 -8.827567 -6.534637
# 2            2  0.001   8000  300.001338  8.718759 -8.697445 -6.676893
# 3            3  0.001   7000  300.001411  8.578956 -8.538250 -6.729288
# 4            4  0.001   6000  300.001161  8.447988 -8.423157 -6.922978
# ..         ...    ...    ...         ...       ...       ...       ...
# 57          57  0.001   6000  300.000816  8.748374 -8.753706 -7.244777
# 58          58  0.001   7000  300.001489  8.936293 -8.945782 -7.130479
# 59          59  0.001   8000  300.000549  9.085102 -9.046231 -7.020332
# 60          60  0.001   9000  300.000855  9.236534 -9.202040 -6.893220
# 61          61  0.001  10000  300.001082  9.335323 -9.308013 -6.787625
#
#           V4        V5        V6        V7        V8  multiplier       RHc  \
# ...
