# %% [markdown]
# # A304_SRO_NGO_150K

# %% [markdown]
# How to use Template:
#     i.  Change file Address
#     ii. Set 'truncate' True if the initial data ranges from 0 to Bmax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

# %%
t=150
truncate = False # True it contains data from O to Bmax
path = r"..\..\..\Data\A304\A304_Hall_center_contact"
filename = 'A304_SRO_NGO_150K.csv'
df = pd.read_csv(os.path.join(path, filename), names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value','multiplier'])
df
# Out:
#         I             B           T         V1         V2         V3  \
# 0   0.001  10000.325537  150.078226  62.263339 -62.185494  -7.818697
# 1   0.001   9000.571875  150.008618  60.908278 -60.847888  -9.299169
# 2   0.001   8000.399341  150.003024  59.416619 -59.384261 -10.976955
# 3   0.001   7000.541895  150.000213  57.789445 -57.783292 -12.755123
# 4   0.001   6000.289404  150.000208  56.067635 -56.034039 -14.743245
# ..    ...           ...         ...        ...        ...        ...
# 61  0.001   6000.277100  150.000311  56.406155 -56.395591 -14.861709
# 62  0.001   7000.501880  150.000161  58.206001 -58.165361 -12.926258
# 63  0.001   8000.365137  150.000255  59.832719 -59.805164 -11.154150
# 64  0.001   9000.500293  150.000060  61.329977 -61.306305  -9.542739
# 65  0.001  10000.432422  150.000481  62.723374 -62.696134  -8.034787
#
#            V4     Rel_value  multiplier
# 0    7.868736  1.187200e-06   1000000.0
# 1    9.355271  9.829000e-07   1000000.0
# 2   11.033580  8.892000e-07   1000000.0
# 3   12.828377  8.542000e-07   1000000.0
# 4   14.805780  8.419000e-07   1000000.0
# ..        ...           ...         ...
# 61  14.938593  6.643000e-07   1000000.0
# 62  12.998695  6.661000e-07   1000000.0
# 63  11.245561  6.657000e-07   1000000.0
# 64   9.617448  6.636000e-07   1000000.0
# 65   8.100828  6.667000e-07   1000000.0
#
# [66 rows x 9 columns]

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B','B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T         V1         V2         V3  \
# 0  0.001  10000.325537  10000  150.078226  62.263339 -62.185494  -7.818697
# 1  0.001   9000.571875   9000  150.008618  60.908278 -60.847888  -9.299169
# 2  0.001   8000.399341   8000  150.003024  59.416619 -59.384261 -10.976955
# 3  0.001   7000.541895   7000  150.000213  57.789445 -57.783292 -12.755123
# 4  0.001   6000.289404   6000  150.000208  56.067635 -56.034039 -14.743245
#
#           V4     Rel_value  multiplier
# 0   7.868736  1.187200e-06   1000000.0
# 1   9.355271  9.829000e-07   1000000.0
# 2  11.033580  8.892000e-07   1000000.0
# 3  12.828377  8.542000e-07   1000000.0
# 4  14.805780  8.419000e-07   1000000.0

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ### Truncating intial data (0 to 1 T)

# %%
if(truncate):
    B_max = max(df['B_int'])
    B_max_first_idx = 0
    for i in range(len(df)):
        if df.iloc[i].B_int == B_max:
            B_max_first_idx = i
            break
    print(B_max_first_idx)

    df = df.iloc[B_max_first_idx+1:].copy()
    df.reset_index(inplace = True, drop = True) # resetting index

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 32

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T         V1         V2         V3  \
# 0  0.001  10000.325537  10000  150.078226  62.263339 -62.185494  -7.818697
# 1  0.001   9000.571875   9000  150.008618  60.908278 -60.847888  -9.299169
# 2  0.001   8000.399341   8000  150.003024  59.416619 -59.384261 -10.976955
# 3  0.001   7000.541895   7000  150.000213  57.789445 -57.783292 -12.755123
# 4  0.001   6000.289404   6000  150.000208  56.067635 -56.034039 -14.743245
#
#           V4     Rel_value  multiplier
# 0   7.868736  1.187200e-06   1000000.0
# 1   9.355271  9.829000e-07   1000000.0
# 2  11.033580  8.892000e-07   1000000.0
# 3  12.828377  8.542000e-07   1000000.0
# 4  14.805780  8.419000e-07   1000000.0

# %%
df_inc.head()
# Out:
#         I             B  B_int           T         V1         V2         V3  \
# 33  0.001 -10000.401758 -10000  149.999899   8.020534  -7.992970 -62.576910
# 34  0.001  -9000.455127  -9000  150.000238   9.577316  -9.548513 -61.177456
# 35  0.001  -8000.493335  -8000  150.000615  11.199065 -11.173692 -59.674354
# 36  0.001  -7000.430835  -7000  150.000115  12.984984 -12.933843 -58.044554
# 37  0.001  -6000.427197  -6000  150.000468  14.910707 -14.895272 -56.270961
#
#            V4     Rel_value  multiplier
# 33  62.647056  6.586000e-07   1000000.0
# 34  61.274383  6.589000e-07   1000000.0
# 35  59.762299  6.640000e-07   1000000.0
# 36  58.130631  6.663000e-07   1000000.0
# 37  56.340601  6.617000e-07   1000000.0

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data_dec = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data_dec = data_dec[data_dec['B_int_x'] == -1*data_dec['B_int_y']] # selecting 
data_dec = data_dec[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data_dec.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data_dec.reset_index(inplace = True, drop = True) # resetting index
data_dec.head()
# Out:
#        I      B           T         V1         V2         V3         V4  \
# 0  0.001  10000  150.078226  62.263339 -62.185494  -7.818697   7.868736
# 1  0.001   9000  150.008618  60.908278 -60.847888  -9.299169   9.355271
# 2  0.001   8000  150.003024  59.416619 -59.384261 -10.976955  11.033580
# 3  0.001   7000  150.000213  57.789445 -57.783292 -12.755123  12.828377
# 4  0.001   6000  150.000208  56.067635 -56.034039 -14.743245  14.805780
#
#           V5         V6         V7         V8  multiplier
# 0   8.020534  -7.992970 -62.576910  62.647056   1000000.0
# 1   9.577316  -9.548513 -61.177456  61.274383   1000000.0
# 2  11.199065 -11.173692 -59.674354  59.762299   1000000.0
# 3  12.984984 -12.933843 -58.044554  58.130631   1000000.0
# 4  14.910707 -14.895272 -56.270961  56.340601   1000000.0

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data_dec['RHc'] = (-data_dec['V2'] + data_dec['V1'] - data_dec['V5'] + data_dec['V6'])/(data_dec['I']*data_dec['multiplier'])
data_dec['RHd'] = (-data_dec['V4'] + data_dec['V3'] - data_dec['V7'] + data_dec['V8'])/(data_dec['I']*data_dec['multiplier'])
data_dec['R'] = (data_dec['RHc'] + data_dec['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data_dec['B'],data_dec['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data_dec['B'],data_dec['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data_dec['B'],data_dec['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data_inc = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data_inc = data_inc[data_inc['B_int_x'] == -1*data_inc['B_int_y']] # selecting 
data_inc = data_inc[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data_inc.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data_inc.reset_index(inplace = True, drop = True) # resetting index
data_inc.head()
# Out:
#        I      B           T         V1         V2         V3         V4  \
# 0  0.001 -10000  149.999899   8.020534  -7.992970 -62.576910  62.647056
# 1  0.001  -9000  150.000238   9.577316  -9.548513 -61.177456  61.274383
# 2  0.001  -8000  150.000615  11.199065 -11.173692 -59.674354  59.762299
# 3  0.001  -7000  150.000115  12.984984 -12.933843 -58.044554  58.130631
# 4  0.001  -6000  150.000468  14.910707 -14.895272 -56.270961  56.340601
#
#           V5         V6         V7         V8  multiplier
# 0  62.263339 -62.185494  -7.818697   7.868736   1000000.0
# 1  60.908278 -60.847888  -9.299169   9.355271   1000000.0
# 2  59.416619 -59.384261 -10.976955  11.033580   1000000.0
# 3  57.789445 -57.783292 -12.755123  12.828377   1000000.0
# 4  56.067635 -56.034039 -14.743245  14.805780   1000000.0

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data_inc['RHc'] = (-data_inc['V2'] + data_inc['V1'] - data_inc['V5'] + data_inc['V6'])/(data_inc['I']*data_inc['multiplier'])
data_inc['RHd'] = (-data_inc['V4'] + data_inc['V3'] - data_inc['V7'] + data_inc['V8'])/(data_inc['I']*data_inc['multiplier'])

data_inc['R'] = (data_inc['RHc'] + data_inc['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data_inc['B'],data_inc['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data_inc['B'],data_inc['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data_inc['B'],data_inc['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data_dec['B'], data_dec['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data_inc['B'],data_inc['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()

# %%
data = pd.concat([data_dec,data_inc])
folder = "Processed_data"
loc = os.path.join(folder, filename)
try: 
    os.mkdir(folder) 
except: pass
data.reset_index(drop=True, inplace = True)
data.to_csv(f'{loc}')

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['RHc'], 'ro-', linewidth=0.8, markersize=3, label = 'RHc')
plt.plot(data['B'],data['RHd'],'bo-', linewidth=0.8, markersize=3, label = 'RHd')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')

plt.legend()
plt.show()

# %%
data.to_pickle(f"./pickle_data/HALL_CENTRALCONTACT_{t}K.pkl")
