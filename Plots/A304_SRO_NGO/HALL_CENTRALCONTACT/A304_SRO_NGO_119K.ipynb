# %% [markdown]
#   # A304_SRO_NGO_119K

# %% [markdown]
# How to use Template:
#     i.  Change file Address
#     ii. Set 'truncate' True if the initial data ranges from 0 to Bmax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

# %%
t=119
truncate = False # True it contains data from O to Bmax
path =r"..\..\..\Data\A304\A304_Hall_center_contact"
filename = 'A304_SRO_NGO_119K.csv'
df = pd.read_csv(os.path.join(path, filename), names=["I", "B","T", "V1", "V2", "V3", "V4",'Rel_value','multiplier'])
df
# Out:
#         I             B           T         V1         V2         V3  \
# 0   0.001  10000.491602  118.961311  12.921284 -12.937216 -20.250490
# 1   0.001   9000.505176  119.003813  13.445751 -13.427209 -19.765433
# 2   0.001   8000.376514  119.001814  13.851966 -13.832419 -19.377520
# 3   0.001   7000.483936  118.999149  14.245855 -14.185559 -18.963525
# 4   0.001   6000.489307  118.998662  14.600209 -14.555904 -18.576614
# ..    ...           ...         ...        ...        ...        ...
# 61  0.001   6000.335913  119.000209  14.671383 -14.642323 -18.523850
# 62  0.001   7000.332104  119.000454  14.251507 -14.263588 -18.958464
# 63  0.001   8000.230347  119.000270  13.863595 -13.846271 -19.407346
# 64  0.001   9000.349121  119.000414  13.501037 -13.468151 -19.810213
# 65  0.001  10000.503027  119.000273  13.108368 -13.084469 -20.226141
#
#            V4     Rel_value  multiplier
# 0   20.267837  4.880000e-07   1000000.0
# 1   19.801877  4.704000e-07   1000000.0
# 2   19.406379  4.711000e-07   1000000.0
# 3   19.004208  4.904000e-07   1000000.0
# 4   18.624878  4.856000e-07   1000000.0
# ..        ...           ...         ...
# 61  18.551904  5.366000e-07   1000000.0
# 62  18.985001  5.529000e-07   1000000.0
# 63  19.419730  5.431000e-07   1000000.0
# 64  19.837565  5.526000e-07   1000000.0
# 65  20.251964  5.577000e-07   1000000.0
#
# [66 rows x 9 columns]

# %% [markdown]
# ### Converting B to integer B

# %%
def round_fun(a):
    step = 500
    if a > 0 : q = int((a+1)/step)
    else : q = int((a-1)/step)
    return q*step

df['B_int'] = list(map(round_fun,df['B'].values))
df = df[['I', 'B','B_int', 'T', 'V1', 'V2', 'V3', 'V4', 'Rel_value', 'multiplier']].copy()

# %%
df.head()
# Out:
#        I             B  B_int           T         V1         V2         V3  \
# 0  0.001  10000.491602  10000  118.961311  12.921284 -12.937216 -20.250490
# 1  0.001   9000.505176   9000  119.003813  13.445751 -13.427209 -19.765433
# 2  0.001   8000.376514   8000  119.001814  13.851966 -13.832419 -19.377520
# 3  0.001   7000.483936   7000  118.999149  14.245855 -14.185559 -18.963525
# 4  0.001   6000.489307   6000  118.998662  14.600209 -14.555904 -18.576614
#
#           V4     Rel_value  multiplier
# 0  20.267837  4.880000e-07   1000000.0
# 1  19.801877  4.704000e-07   1000000.0
# 2  19.406379  4.711000e-07   1000000.0
# 3  19.004208  4.904000e-07   1000000.0
# 4  18.624878  4.856000e-07   1000000.0

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ### Truncating intial data (0 to 1 T)

# %%
if(truncate):
    B_max = max(df['B_int'])
    B_max_first_idx = 0
    for i in range(len(df)):
        if df.iloc[i].B_int == B_max:
            B_max_first_idx = i
            break
    print(B_max_first_idx)

    df = df.iloc[B_max_first_idx+1:].copy()
    df.reset_index(inplace = True, drop = True) # resetting index

# %%
data_temp = df.copy()
data_temp['R1'] = df['V1']/(df['multiplier']*df['I'])
data_temp['R2'] = df['V2']/(df['multiplier']*df['I'])
data_temp['R3'] = df['V3']/(df['multiplier']*df['I'])
data_temp['R4'] = df['V4']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(18,18))
plt.subplot(2,2,1)
plt.plot(data_temp['B'],data_temp['R1'], 'bo-')
plt.title('R1 vs B')
plt.ylabel('R1')
plt.xlabel('B')
plt.subplot(2,2,2)
plt.plot(data_temp['B'],data_temp['R2'], 'bo-')
plt.title('R2 vs B')
plt.ylabel('R2')
plt.xlabel('B')
plt.subplot(2,2,3)
plt.plot(data_temp['B'],data_temp['R3'], 'bo-')
plt.title('R3 vs B')
plt.ylabel('R3')
plt.xlabel('B')
plt.subplot(2,2,4)
plt.plot(data_temp['B'],data_temp['R4'], 'bo-')
plt.title('R4 vs B')
plt.ylabel('R4')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %% [markdown]
# ## Spliting data into two subset (increasing and decreasing of magnetic field)
#
# B_max to B_min --> Decreasing
#
# B_min to B_max --> increasing

# %%
B_max = max(df['B_int'])
B_min = min(df['B_int'])
print(B_max, B_min)
# Out:
# 10000 -10000

# %%
# finding index of first appearance of B_min
B_min_first_idx = 0
for i in range(len(df)):
    if df.iloc[i].B_int == B_min:
        B_min_first_idx = i
        break
B_min_first_idx
# Out:
# 32

# %%
# now split it into two data set
df_dec = df.iloc[0:B_min_first_idx+1].copy()
df_inc = df.iloc[B_min_first_idx+1:].copy()

# %%
df_dec.head()
# Out:
#        I             B  B_int           T         V1         V2         V3  \
# 0  0.001  10000.491602  10000  118.961311  12.921284 -12.937216 -20.250490
# 1  0.001   9000.505176   9000  119.003813  13.445751 -13.427209 -19.765433
# 2  0.001   8000.376514   8000  119.001814  13.851966 -13.832419 -19.377520
# 3  0.001   7000.483936   7000  118.999149  14.245855 -14.185559 -18.963525
# 4  0.001   6000.489307   6000  118.998662  14.600209 -14.555904 -18.576614
#
#           V4     Rel_value  multiplier
# 0  20.267837  4.880000e-07   1000000.0
# 1  19.801877  4.704000e-07   1000000.0
# 2  19.406379  4.711000e-07   1000000.0
# 3  19.004208  4.904000e-07   1000000.0
# 4  18.624878  4.856000e-07   1000000.0

# %%
df_inc.head()
# Out:
#         I             B  B_int           T         V1         V2         V3  \
# 33  0.001 -10000.474463 -10000  119.000583  20.381840 -20.339931 -13.175443
# 34  0.001  -9000.526123  -9000  119.000417  19.967247 -19.935033 -13.545276
# 35  0.001  -8000.340576  -8000  119.000492  19.585777 -19.546495 -13.952990
# 36  0.001  -7000.483984  -7000  119.000151  19.187364 -19.142922 -14.337492
# 37  0.001  -6000.241846  -6000  119.000212  18.800046 -18.760253 -14.724503
#
#            V4     Rel_value  multiplier
# 33  13.197616  5.386000e-07   1000000.0
# 34  13.598472  5.381000e-07   1000000.0
# 35  14.013579  5.149000e-07   1000000.0
# 36  14.380876  5.469000e-07   1000000.0
# 37  14.753548  5.498000e-07   1000000.0

# %%
df_dec.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates
df_inc.drop_duplicates(subset='B_int', keep='first', inplace=True) # remove duplicates

# %% [markdown]
# ## Creating decreasing Field data

# %%
data_dec = pd.merge(df_dec.assign(key=1), df_inc.assign(key=1), on='key').drop('key', axis=1) # cross product

data_dec = data_dec[data_dec['B_int_x'] == -1*data_dec['B_int_y']] # selecting 
data_dec = data_dec[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data_dec.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data_dec.reset_index(inplace = True, drop = True) # resetting index
data_dec.head()
# Out:
#        I      B           T         V1         V2         V3         V4  \
# 0  0.001  10000  118.961311  12.921284 -12.937216 -20.250490  20.267837
# 1  0.001   9000  119.003813  13.445751 -13.427209 -19.765433  19.801877
# 2  0.001   8000  119.001814  13.851966 -13.832419 -19.377520  19.406379
# 3  0.001   7000  118.999149  14.245855 -14.185559 -18.963525  19.004208
# 4  0.001   6000  118.998662  14.600209 -14.555904 -18.576614  18.624878
#
#           V5         V6         V7         V8  multiplier
# 0  20.381840 -20.339931 -13.175443  13.197616   1000000.0
# 1  19.967247 -19.935033 -13.545276  13.598472   1000000.0
# 2  19.585777 -19.546495 -13.952990  14.013579   1000000.0
# 3  19.187364 -19.142922 -14.337492  14.380876   1000000.0
# 4  18.800046 -18.760253 -14.724503  14.753548   1000000.0

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data_dec['RHc'] = (-data_dec['V2'] + data_dec['V1'] - data_dec['V5'] + data_dec['V6'])/(data_dec['I']*data_dec['multiplier'])
data_dec['RHd'] = (-data_dec['V4'] + data_dec['V3'] - data_dec['V7'] + data_dec['V8'])/(data_dec['I']*data_dec['multiplier'])
data_dec['R'] = (data_dec['RHc'] + data_dec['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data_dec['B'],data_dec['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data_dec['B'],data_dec['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data_dec['B'],data_dec['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Creating Increasing Field data

# %%
data_inc = pd.merge(df_inc.assign(key=1), df_dec.assign(key=1), on='key').drop('key', axis=1) # cross product

data_inc = data_inc[data_inc['B_int_x'] == -1*data_inc['B_int_y']] # selecting 
data_inc = data_inc[['I_x','B_int_x','T_x','V1_x','V2_x','V3_x','V4_x','V1_y','V2_y','V3_y','V4_y','multiplier_x']].copy() # req coloumns

data_inc.rename({'I_x' : 'I', 'B_int_x' : 'B', 'T_x' : 'T', 'V1_x' : 'V1', 'V2_x' : 'V2', 'V3_x' : 'V3', 'V4_x' : 'V4', 'V1_y' : 'V5', 'V2_y' : 'V6', 'V3_y' : 'V7', 'V4_y' : 'V8', 'multiplier_x' : 'multiplier'}, axis=1, inplace=True)
data_inc.reset_index(inplace = True, drop = True) # resetting index
data_inc.head()
# Out:
#        I      B           T         V1         V2         V3         V4  \
# 0  0.001 -10000  119.000583  20.381840 -20.339931 -13.175443  13.197616
# 1  0.001  -9000  119.000417  19.967247 -19.935033 -13.545276  13.598472
# 2  0.001  -8000  119.000492  19.585777 -19.546495 -13.952990  14.013579
# 3  0.001  -7000  119.000151  19.187364 -19.142922 -14.337492  14.380876
# 4  0.001  -6000  119.000212  18.800046 -18.760253 -14.724503  14.753548
#
#           V5         V6         V7         V8  multiplier
# 0  12.921284 -12.937216 -20.250490  20.267837   1000000.0
# 1  13.445751 -13.427209 -19.765433  19.801877   1000000.0
# 2  13.851966 -13.832419 -19.377520  19.406379   1000000.0
# 3  14.245855 -14.185559 -18.963525  19.004208   1000000.0
# 4  14.600209 -14.555904 -18.576614  18.624878   1000000.0

# %% [markdown]
# ### Hall resistance calculation
#
# ![image.png](attachment:image.png)
#
# ## Note : Here RHc & RHd we computed is Hall resistance, not Hall coefficients.

# %%
data_inc['RHc'] = (-data_inc['V2'] + data_inc['V1'] - data_inc['V5'] + data_inc['V6'])/(data_inc['I']*data_inc['multiplier'])
data_inc['RHd'] = (-data_inc['V4'] + data_inc['V3'] - data_inc['V7'] + data_inc['V8'])/(data_inc['I']*data_inc['multiplier'])

data_inc['R'] = (data_inc['RHc'] + data_inc['RHd'])/2

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(data_inc['B'],data_inc['RHc'],'bo-')
plt.title('RHc vs B')
plt.ylabel('RHc')
plt.xlabel('B')
plt.subplot(1,2,2)
plt.plot(data_inc['B'],data_inc['RHd'],'bo-')
plt.title('RHd vs B')
plt.ylabel('RHd')
plt.xlabel('B')
plt.subplots_adjust(hspace = 0, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(data_inc['B'],data_inc['R'],'bo-', linewidth=0.8, markersize=3)
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.show()

# %% [markdown]
# ## Plotting on same graph

# %%
plt.figure(figsize=(8,5))
plt.plot(data_dec['B'], data_dec['R'], 'ro-', linewidth=0.8, markersize=3, label = 'Decreasing Field')
plt.plot(data_inc['B'],data_inc['R'],'bo-', linewidth=0.8, markersize=3, label = 'Increasing Field')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')
plt.legend()
plt.show()

# %%
data = pd.concat([data_dec,data_inc])
folder = "Processed_data"
loc = os.path.join(folder, filename)
try: 
    os.mkdir(folder) 
except: pass
data.reset_index(drop=True, inplace = True)
data.to_csv(f'{loc}')

# %%
plt.figure(figsize=(8,5))
plt.plot(data['B'], data['RHc'], 'ro-', linewidth=0.8, markersize=3, label = 'RHc')
plt.plot(data['B'],data['RHd'],'bo-', linewidth=0.8, markersize=3, label = 'RHd')
plt.title('R vs B')
plt.ylabel('R')
plt.xlabel('B')

plt.legend()
plt.show()

# %%
data.to_pickle(f"./pickle_data/HALL_CENTRALCONTACT_{t}K.pkl")

# %%
temp = data[data['B'] == 10000]
(temp['RHc'] - temp['RHd'])/(temp['RHc'])*100
# Out:
# 0     4.830714
# 61    3.119234
# dtype: float64

# %% [markdown]
# #
