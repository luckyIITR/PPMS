# %% [markdown]
# # For VDP with Temperature
# Use for VDP with temperature variation.
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename= r'..\..\..\Data\A304\A304_RT_center_contact\A304_SRO_NGO_136K_168K_RT.csv'
df = pd.read_csv(filename, names=["T_S", "T","B", "I", "V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8"])
df['multiplier'] = 10**6
df
# Out:
#       T_S           T         B      I           V1           V2           V3  \
# 0   125.0  125.043672  0.355126  0.001  4982.530153 -4982.397125  4964.776588
# 1   125.5  125.522714  0.372270  0.001  5002.633200 -5002.721835  4985.242559
# 2   126.0  126.022897  0.389414  0.001  5023.645906 -5023.863633  5006.282166
# 3   126.5  126.522839  0.398394  0.001  5044.877543 -5045.030521  5027.407995
# 4   127.0  127.022622  0.410640  0.001  5066.091338 -5066.320611  5048.704696
# ..    ...         ...       ...    ...          ...          ...          ...
# 95  172.5  172.520985  0.359208  0.001  6561.729940 -6561.880437  6537.192031
# 96  173.0  173.021355  0.355126  0.001  6571.968774 -6572.021710  6547.371200
# 97  173.5  173.521120  0.380434  0.001  6582.200140 -6582.276988  6557.603293
# 98  174.0  174.021859  0.360841  0.001  6592.383846 -6592.529851  6567.731679
# 99  174.5  174.521575  0.390231  0.001  6602.553831 -6602.654560  6577.928092
#
#              V4           V5           V6           V7           V8  \
# 0  -4964.669404  4982.770020 -4982.660461  4964.613636 -4964.577788
# 1  -4985.287194  5003.454502 -5003.483795  4985.334868 -4985.252217
# 2  -5006.251470  5024.549047 -5024.502215  5006.273497 -5006.284210
# 3  -5027.375094  5045.785509 -5045.704865  5027.393524 -5027.390108
# 4  -5048.638592  5067.034201 -5067.057796  5048.561840 -5048.596591
# ..          ...          ...          ...          ...          ...
# 95 -6537.212964  6561.902206 -6561.952077  6537.219633 -6537.213787
# 96 -6547.361544  6572.115663 -6572.214623  6547.407950 -6547.418723
# 97 -6557.570452  6582.296833 -6582.368122  6557.576520 -6557.601102
# 98 -6567.677806  6592.578474 -6592.551544  6567.697108 -6567.685837
# 99 -6577.884935  6602.820485 -6602.796807  6577.879839 -6577.881656
#
#     multiplier
# 0      1000000
# 1      1000000
# 2      1000000
# 3      1000000
# 4      1000000
# ..         ...
# 95     1000000
# 96     1000000
# 97     1000000
# 98     1000000
# 99     1000000
#
# [100 rows x 13 columns]

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])
df['R5'] = df['V5']/(df['multiplier']*df['I'])
df['R6'] = df['V6']/(df['multiplier']*df['I'])
df['R7'] = df['V7']/(df['multiplier']*df['I'])
df['R8'] = df['V8']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.plot(df['T'],df['R1'])
plt.title('R1 vs T')
plt.ylabel('R1')
plt.xlabel('T')
plt.subplot(2,4,2)
plt.plot(df['T'],df['R2'])
plt.title('R2 vs T')
plt.ylabel('R2')
plt.xlabel('T')
plt.subplot(2,4,3)
plt.plot(df['T'],df['R3'])
plt.title('R3 vs T')
plt.ylabel('R3')
plt.xlabel('T')
plt.subplot(2,4,4)
plt.plot(df['T'],df['R4'])
plt.title('R4 vs T')
plt.ylabel('R4')
plt.xlabel('T')
plt.subplot(2,4,5)
plt.plot(df['T'],df['R5'])
plt.title('R5 vs T')
plt.ylabel('R5')
plt.xlabel('T')
plt.subplot(2,4,6)
plt.plot(df['T'],df['R6'])
plt.title('R6 vs T')
plt.ylabel('R6')
plt.xlabel('T')
plt.subplot(2,4,7)
plt.plot(df['T'],df['R7'])
plt.title('R7 vs T')
plt.ylabel('R7')
plt.xlabel('T')
plt.subplot(2,4,8)
plt.plot(df['T'],df['R8'])
plt.title('R8 vs T')
plt.ylabel('R8')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.4, wspace = 0.6)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],1*df['R1'],'go',label='R1')
plt.plot(df['T'],-1*df['R2'],label='R2')
plt.plot(df['T'],1*df['R3'],'bo',label='R3')
plt.plot(df['T'],-1*df['R4'],label='R4')
plt.plot(df['T'],1*df['R5'],'ro',label='R5')
plt.plot(df['T'],-1*df['R6'],label='R6')
plt.plot(df['T'],1*df['R7'],'yo',label='R7')
plt.plot(df['T'],-1*df['R8'],label='R8')
plt.title('R_all vs T',fontsize=30)
plt.ylabel('R_all',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.legend()
plt.show()

# %%
df['R12']=(df['V1']-df['V2'])/(df['multiplier']*df['I']*2)
df['R34']=(df['V3']-df['V4'])/(df['multiplier']*df['I']*2)
df['R56']=(df['V5']-df['V6'])/(df['multiplier']*df['I']*2)
df['R78']=(df['V7']-df['V8'])/(df['multiplier']*df['I']*2)

# %%
plt.figure(figsize=(17,13))
plt.subplot(2,2,1)
plt.plot(df['T'],df['R12'],'bo-')
plt.title('R12 vs T')
plt.ylabel('R12')
plt.xlabel('T')
plt.subplot(2,2,2)
plt.plot(df['T'],df['R34'],'bo-')
plt.title('R34 vs T')
plt.ylabel('R34')
plt.xlabel('T')
plt.subplot(2,2,3)
plt.plot(df['T'],df['R56'],'bo-')
plt.title('R56 vs T')
plt.ylabel('R56')
plt.xlabel('T')
plt.subplot(2,2,4)
plt.plot(df['T'],df['R78'],'bo-')
plt.title('R78 vs T')
plt.ylabel('R78')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R_a']=(df['V1']-df['V2']+df['V5']-df['V6'])/(4*df['multiplier']*df['I'])
df['R_b']=(df['V3']-df['V4']+df['V7']-df['V8'])/(4*df['multiplier']*df['I'])

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(df['T'],df['R_a'],'bo-')
plt.title('R_a vs T',fontsize=30)
plt.ylabel('R_a',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplot(1,2,2)
plt.plot(df['T'],df['R_b'],'bo-')
plt.title('R_b vs T',fontsize=30)
plt.ylabel('R_b',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df['T'],df['R_a'],'go-')
plt.ylabel('R',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.plot(df['T'],df['R_b'],'bo-')
plt.show()

# %%
df['R']=(df['R_a']+df['R_b'])/2

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],df['R'],'go-')
plt.title('R vs T',fontsize=30)
plt.ylabel('R',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.show()
