# %% [markdown]
# # For VDP with Temperature
# Use for VDP with temperature variation.
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename='C:\\Users\\Admin\\Desktop\\Analysis\\Data\\16_Aug\\A302_SRO_DSO_RT_0T_300K_to_2K_Cool_V2.csv'
df = pd.read_csv(filename, names=["T_S", "T","B", "I", "V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8"])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#        T_S           T         B       I        V1        V2        V3  \
# 0    300.0  300.000557  0.487380  0.0002 -0.001925  0.001881 -0.002137
# 1    298.0  297.949841  0.484115  0.0002 -0.001919  0.001873 -0.002131
# 2    296.0  295.947374  0.469420  0.0002 -0.001910  0.001866 -0.002122
# 3    294.0  293.949185  0.484115  0.0002 -0.001902  0.001858 -0.002113
# 4    292.0  291.949437  0.500442  0.0002 -0.001892  0.001850 -0.002109
# ..     ...         ...       ...     ...       ...       ...       ...
# 144   12.0   12.000114  0.023675  0.0002 -0.000451  0.000367 -0.000474
# 145   10.0    9.999645  0.015511  0.0002 -0.000438  0.000366 -0.000465
# 146    8.0    7.997326  0.032655  0.0002 -0.000445  0.000358 -0.000468
# 147    6.0    6.000041  0.018777  0.0002 -0.000443  0.000354 -0.000465
# 148    4.0    3.998811  0.034288  0.0002 -0.000430  0.000357 -0.000456
#
#            V4        V5        V6        V7        V8  multiplier
# 0    0.002084 -0.001946  0.001873 -0.002142  0.002085     1000000
# 1    0.002076 -0.001939  0.001864 -0.002136  0.002078     1000000
# 2    0.002069 -0.001932  0.001856 -0.002128  0.002071     1000000
# 3    0.002062 -0.001921  0.001850 -0.002120  0.002064     1000000
# 4    0.002055 -0.001914  0.001843 -0.002113  0.002058     1000000
# ..        ...       ...       ...       ...       ...         ...
# 144  0.000423 -0.000501  0.000315 -0.000531  0.000394     1000000
# 145  0.000419 -0.000485  0.000321 -0.000509  0.000396     1000000
# 146  0.000414 -0.000496  0.000306 -0.000523  0.000386     1000000
# 147  0.000411 -0.000492  0.000304 -0.000520  0.000383     1000000
# 148  0.000410 -0.000472  0.000317 -0.000497  0.000388     1000000
#
# [149 rows x 13 columns]

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])
df['R5'] = df['V5']/(df['multiplier']*df['I'])
df['R6'] = df['V6']/(df['multiplier']*df['I'])
df['R7'] = df['V7']/(df['multiplier']*df['I'])
df['R8'] = df['V8']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.plot(df['T'],df['R1'])
plt.title('R1 vs T')
plt.ylabel('R1')
plt.xlabel('T')
plt.subplot(2,4,2)
plt.plot(df['T'],df['R2'])
plt.title('R2 vs T')
plt.ylabel('R2')
plt.xlabel('T')
plt.subplot(2,4,3)
plt.plot(df['T'],df['R3'])
plt.title('R3 vs T')
plt.ylabel('R3')
plt.xlabel('T')
plt.subplot(2,4,4)
plt.plot(df['T'],df['R4'])
plt.title('R4 vs T')
plt.ylabel('R4')
plt.xlabel('T')
plt.subplot(2,4,5)
plt.plot(df['T'],df['R5'])
plt.title('R5 vs T')
plt.ylabel('R5')
plt.xlabel('T')
plt.subplot(2,4,6)
plt.plot(df['T'],df['R6'])
plt.title('R6 vs T')
plt.ylabel('R6')
plt.xlabel('T')
plt.subplot(2,4,7)
plt.plot(df['T'],df['R7'])
plt.title('R7 vs T')
plt.ylabel('R7')
plt.xlabel('T')
plt.subplot(2,4,8)
plt.plot(df['T'],df['R8'])
plt.title('R8 vs T')
plt.ylabel('R8')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.4, wspace = 0.6)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],-1*df['R1'],'go',label='R1')
plt.plot(df['T'],1*df['R2'],label='R2')
plt.plot(df['T'],-1*df['R3'],'bo',label='R3')
plt.plot(df['T'],1*df['R4'],label='R4')
plt.plot(df['T'],-1*df['R5'],'ro',label='R5')
plt.plot(df['T'],1*df['R6'],label='R6')
plt.plot(df['T'],-1*df['R7'],'yo',label='R7')
plt.plot(df['T'],1*df['R8'],label='R8')
plt.title('R_all vs T',fontsize=30)
plt.ylabel('R_all',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.legend()
plt.show()

# %%
df['R12']=-1*(df['V1']-df['V2'])/(df['multiplier']*df['I']*2)
df['R34']=-1*(df['V3']-df['V4'])/(df['multiplier']*df['I']*2)
df['R56']=-1*(df['V5']-df['V6'])/(df['multiplier']*df['I']*2)
df['R78']=-1*(df['V7']-df['V8'])/(df['multiplier']*df['I']*2)

# %%
plt.figure(figsize=(17,13))
plt.subplot(2,2,1)
plt.plot(df['T'],df['R12'],'bo-')
plt.title('R12 vs T')
plt.ylabel('R12')
plt.xlabel('T')
plt.subplot(2,2,2)
plt.plot(df['T'],df['R34'],'bo-')
plt.title('R34 vs T')
plt.ylabel('R34')
plt.xlabel('T')
plt.subplot(2,2,3)
plt.plot(df['T'],df['R56'],'bo-')
plt.title('R56 vs T')
plt.ylabel('R56')
plt.xlabel('T')
plt.subplot(2,2,4)
plt.plot(df['T'],df['R78'],'bo-')
plt.title('R78 vs T')
plt.ylabel('R78')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R_a']=-1*(df['V1']-df['V2']+df['V5']-df['V6'])/(4*df['multiplier']*df['I'])
df['R_b']=-1*(df['V3']-df['V4']+df['V7']-df['V8'])/(4*df['multiplier']*df['I'])

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(df['T'],df['R_a'],'bo-')
plt.title('R_a vs T',fontsize=30)
plt.ylabel('R_a',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplot(1,2,2)
plt.plot(df['T'],df['R_b'],'bo-')
plt.title('R_b vs T',fontsize=30)
plt.ylabel('R_b',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df['T'],df['R_a'],'go-')
plt.ylabel('R',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.plot(df['T'],df['R_b'],'bo-')
plt.show()

# %%
df['R']=(df['R_a']+df['R_b'])/2

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],df['R'],'go-')
plt.title('R vs T',fontsize=30)
plt.ylabel('R',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.show()
