# %% [markdown]
# # For VDP with Temperature
# Use for VDP with temperature variation.
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename='C:\\Users\\Admin\\Desktop\\Analysis\\Plots\\LCMO_PLD2\\RT\\LCMO_PLD2_6K_TO_300K_REPEAT.csv'
df = pd.read_csv(filename, names=["T_S", "T","B", "I", "V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8"])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#      T_S           T         B             I        V1        V2        V3  \
# 0  110.0  109.880179  0.391047  5.000000e-07  0.770399 -1.614144  0.724202
# 1  112.0  111.933854  0.342064  5.000000e-07  0.770984 -1.618154  0.723441
# 2  114.0  113.970371  0.306960  5.000000e-07  0.767784 -1.619213  0.721537
# 3  116.0  115.924984  0.306960  5.000000e-07  0.766917 -1.622178  0.721587
# 4  118.0  117.968296  0.288183  5.000000e-07  0.765006 -1.626901  0.720195
# 5  120.0  119.925406  0.271855  5.000000e-07  0.765977 -1.627362  0.720527
#
#          V4        V5        V6        V7        V8  multiplier
# 0 -1.028414  0.744204 -1.164868  0.757980 -1.385483     1000000
# 1 -1.029646  0.743616 -1.165043  0.754491 -1.382396     1000000
# 2 -1.032424  0.743470 -1.165526  0.755863 -1.378134     1000000
# 3 -1.033621  0.743420 -1.165521  0.754333 -1.373749     1000000
# 4 -1.036791  0.740913 -1.165619  0.752135 -1.370663     1000000
# 5 -1.037623  0.740467 -1.162919  0.749172 -1.366570     1000000

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])
df['R5'] = df['V5']/(df['multiplier']*df['I'])
df['R6'] = df['V6']/(df['multiplier']*df['I'])
df['R7'] = df['V7']/(df['multiplier']*df['I'])
df['R8'] = df['V8']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.plot(df['T'],df['R1'])
plt.title('R1 vs T')
plt.ylabel('R1')
plt.xlabel('T')
plt.subplot(2,4,2)
plt.plot(df['T'],df['R2'])
plt.title('R2 vs T')
plt.ylabel('R2')
plt.xlabel('T')
plt.subplot(2,4,3)
plt.plot(df['T'],df['R3'])
plt.title('R3 vs T')
plt.ylabel('R3')
plt.xlabel('T')
plt.subplot(2,4,4)
plt.plot(df['T'],df['R4'])
plt.title('R4 vs T')
plt.ylabel('R4')
plt.xlabel('T')
plt.subplot(2,4,5)
plt.plot(df['T'],df['R5'])
plt.title('R5 vs T')
plt.ylabel('R5')
plt.xlabel('T')
plt.subplot(2,4,6)
plt.plot(df['T'],df['R6'])
plt.title('R6 vs T')
plt.ylabel('R6')
plt.xlabel('T')
plt.subplot(2,4,7)
plt.plot(df['T'],df['R7'])
plt.title('R7 vs T')
plt.ylabel('R7')
plt.xlabel('T')
plt.subplot(2,4,8)
plt.plot(df['T'],df['R8'])
plt.title('R8 vs T')
plt.ylabel('R8')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.4, wspace = 0.6)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],-1*df['R1'],'go',label='R1')
plt.plot(df['T'],1*df['R2'],label='R2')
plt.plot(df['T'],-1*df['R3'],'bo',label='R3')
plt.plot(df['T'],1*df['R4'],label='R4')
plt.plot(df['T'],-1*df['R5'],'ro',label='R5')
plt.plot(df['T'],1*df['R6'],label='R6')
plt.plot(df['T'],-1*df['R7'],'yo',label='R7')
plt.plot(df['T'],1*df['R8'],label='R8')
plt.title('R_all vs T',fontsize=30)
plt.ylabel('R_all',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.legend()
plt.show()

# %%
df['R12']=-1*(df['V1']-df['V2'])/(df['multiplier']*df['I']*2)
df['R34']=-1*(df['V3']-df['V4'])/(df['multiplier']*df['I']*2)
df['R56']=-1*(df['V5']-df['V6'])/(df['multiplier']*df['I']*2)
df['R78']=-1*(df['V7']-df['V8'])/(df['multiplier']*df['I']*2)
df['R12']
# Out:
# 0   -2.384543
# 1   -2.389138
# 2   -2.386996
# 3   -2.389095
# 4   -2.391907
# 5   -2.393339
# Name: R12, dtype: float64

# %%
plt.figure(figsize=(17,13))
plt.subplot(2,2,1)
plt.plot(df['T'],df['R12'],'bo-')
plt.title('R12 vs T')
plt.ylabel('R12')
plt.xlabel('T')
plt.subplot(2,2,2)
plt.plot(df['T'],df['R34'],'bo-')
plt.title('R34 vs T')
plt.ylabel('R34')
plt.xlabel('T')
plt.subplot(2,2,3)
plt.plot(df['T'],df['R56'],'bo-')
plt.title('R56 vs T')
plt.ylabel('R56')
plt.xlabel('T')
plt.subplot(2,2,4)
plt.plot(df['T'],df['R78'],'bo-')
plt.title('R78 vs T')
plt.ylabel('R78')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R_a']=-1*(df['V1']-df['V2']+df['V5']-df['V6'])/(4*df['multiplier']*df['I'])
df['R_b']=-1*(df['V3']-df['V4']+df['V7']-df['V8'])/(4*df['multiplier']*df['I'])

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(df['T'],df['R_a'],'bo-')
plt.title('R_a vs T',fontsize=30)
plt.ylabel('R_a',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplot(1,2,2)
plt.plot(df['T'],df['R_b'],'bo-')
plt.title('R_b vs T',fontsize=30)
plt.ylabel('R_b',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df['T'],df['R_a'],'go-')
plt.ylabel('R',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.plot(df['T'],df['R_b'],'bo-')
plt.show()

# %%
df['R']=(df['R_a']+df['R_b'])/2

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],df['R'],'go-')
plt.title('R vs T',fontsize=30)
plt.ylabel('R',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.show()
