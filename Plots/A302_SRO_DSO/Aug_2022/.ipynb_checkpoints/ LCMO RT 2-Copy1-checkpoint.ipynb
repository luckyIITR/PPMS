# %% [markdown]
# # For VDP with Temperature
# Use for VDP with temperature variation.
# Output plots : <br>
# R1 through R8 vs T together <br>
# R_12 vs T ( R_12 uses the formula R_12 = (V2-V1)/I ) <br>
# R_34 vs T (R_34 uses the formula R_34 = (V4-V3)/I) <br>
# R_56 <br>
# R_78 <br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename='C:\\Users\\Admin\\Desktop\\Analysis\\Data\\LCMO_PLD2\\RT\\LCMO_PLD2_6K_TO_300K.csv'
df = pd.read_csv(filename, names=["T_S", "T","B", "I", "V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8"])
df['multiplier'] = 10**6
df
# NEED TO ADD MULITPLIER IN THE LABVIEW CODE
# Out:
#        T_S           T         B             I        V1        V2        V3  \
# 0      6.0    6.000176  0.302061  1.000000e-07  0.074782 -0.072852  0.102093
# 1      8.0    8.002422  0.342064  1.000000e-07  0.068135 -0.066945  0.096377
# 2     10.0   10.003472  0.342880  1.000000e-07  0.065335 -0.064162  0.092984
# 3     12.0   12.004183  0.375536  1.000000e-07  0.063526 -0.062052  0.090917
# 4     14.0   14.005031  0.397578  1.000000e-07  0.061779 -0.060905  0.089692
# ..     ...         ...       ...           ...       ...       ...       ...
# 122  250.0  249.880012  0.119192  1.000000e-07  0.038525 -0.039522  0.034725
# 123  252.0  251.875385  0.160011  1.000000e-07  0.035871 -0.036416  0.032360
# 124  254.0  253.872823  0.152663  1.000000e-07  0.033223 -0.033489  0.030100
# 125  256.0  255.868726  0.146132  1.000000e-07  0.030744 -0.030840  0.028006
# 126  258.0  257.860722  0.176339  1.000000e-07  0.028480 -0.028544  0.026072
#
#            V4        V5        V6        V7        V8  multiplier
# 0   -0.101313  0.075796 -0.074035  0.110510 -0.108325     1000000
# 1   -0.095129  0.070181 -0.068691  0.103531 -0.101757     1000000
# 2   -0.091865  0.066991 -0.065502  0.099634 -0.097954     1000000
# 3   -0.089860  0.065002 -0.063642  0.097340 -0.095759     1000000
# 4   -0.088839  0.063619 -0.062293  0.095856 -0.094313     1000000
# ..        ...       ...       ...       ...       ...         ...
# 122 -0.040054  0.041679 -0.036435  0.039180 -0.036114     1000000
# 123 -0.036967  0.038380 -0.033661  0.036197 -0.033337     1000000
# 124 -0.034292  0.035275 -0.031232  0.033378 -0.030976     1000000
# 125 -0.031557  0.032519 -0.028885  0.030820 -0.028734     1000000
# 126 -0.029111  0.029954 -0.026787  0.028483 -0.026668     1000000
#
# [127 rows x 13 columns]

# %%
df['R1'] = df['V1']/(df['multiplier']*df['I'])
df['R2'] = df['V2']/(df['multiplier']*df['I'])
df['R3'] = df['V3']/(df['multiplier']*df['I'])
df['R4'] = df['V4']/(df['multiplier']*df['I'])
df['R5'] = df['V5']/(df['multiplier']*df['I'])
df['R6'] = df['V6']/(df['multiplier']*df['I'])
df['R7'] = df['V7']/(df['multiplier']*df['I'])
df['R8'] = df['V8']/(df['multiplier']*df['I'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.plot(df['T'],df['R1'])
plt.title('R1 vs T')
plt.ylabel('R1')
plt.xlabel('T')
plt.subplot(2,4,2)
plt.plot(df['T'],df['R2'])
plt.title('R2 vs T')
plt.ylabel('R2')
plt.xlabel('T')
plt.subplot(2,4,3)
plt.plot(df['T'],df['R3'])
plt.title('R3 vs T')
plt.ylabel('R3')
plt.xlabel('T')
plt.subplot(2,4,4)
plt.plot(df['T'],df['R4'])
plt.title('R4 vs T')
plt.ylabel('R4')
plt.xlabel('T')
plt.subplot(2,4,5)
plt.plot(df['T'],df['R5'])
plt.title('R5 vs T')
plt.ylabel('R5')
plt.xlabel('T')
plt.subplot(2,4,6)
plt.plot(df['T'],df['R6'])
plt.title('R6 vs T')
plt.ylabel('R6')
plt.xlabel('T')
plt.subplot(2,4,7)
plt.plot(df['T'],df['R7'])
plt.title('R7 vs T')
plt.ylabel('R7')
plt.xlabel('T')
plt.subplot(2,4,8)
plt.plot(df['T'],df['R8'])
plt.title('R8 vs T')
plt.ylabel('R8')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.4, wspace = 0.6)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],-1*df['R1'],'go',label='R1')
plt.plot(df['T'],1*df['R2'],label='R2')
plt.plot(df['T'],-1*df['R3'],'bo',label='R3')
plt.plot(df['T'],1*df['R4'],label='R4')
plt.plot(df['T'],-1*df['R5'],'ro',label='R5')
plt.plot(df['T'],1*df['R6'],label='R6')
plt.plot(df['T'],-1*df['R7'],'yo',label='R7')
plt.plot(df['T'],1*df['R8'],label='R8')
plt.title('R_all vs T',fontsize=30)
plt.ylabel('R_all',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.legend()
plt.show()

# %%
df['R12']=-1*(df['V1']-df['V2'])/(df['multiplier']*df['I']*2)
df['R34']=-1*(df['V3']-df['V4'])/(df['multiplier']*df['I']*2)
df['R56']=-1*(df['V5']-df['V6'])/(df['multiplier']*df['I']*2)
df['R78']=-1*(df['V7']-df['V8'])/(df['multiplier']*df['I']*2)

# %%
plt.figure(figsize=(17,13))
plt.subplot(2,2,1)
plt.plot(df['T'],df['R12'],'bo-')
plt.title('R12 vs T')
plt.ylabel('R12')
plt.xlabel('T')
plt.subplot(2,2,2)
plt.plot(df['T'],df['R34'],'bo-')
plt.title('R34 vs T')
plt.ylabel('R34')
plt.xlabel('T')
plt.subplot(2,2,3)
plt.plot(df['T'],df['R56'],'bo-')
plt.title('R56 vs T')
plt.ylabel('R56')
plt.xlabel('T')
plt.subplot(2,2,4)
plt.plot(df['T'],df['R78'],'bo-')
plt.title('R78 vs T')
plt.ylabel('R78')
plt.xlabel('T')
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
df['R_a']=-1*(df['V1']-df['V2']+df['V5']-df['V6'])/(4*df['multiplier']*df['I'])
df['R_b']=-1*(df['V3']-df['V4']+df['V7']-df['V8'])/(4*df['multiplier']*df['I'])

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.plot(df['T'],df['R_a'],'bo-')
plt.title('R_a vs T',fontsize=30)
plt.ylabel('R_a',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplot(1,2,2)
plt.plot(df['T'],df['R_b'],'bo-')
plt.title('R_b vs T',fontsize=30)
plt.ylabel('R_b',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df['T'],df['R_a'],'go-')
plt.ylabel('R',fontsize=22)
plt.xlabel('T',fontsize=22)
plt.plot(df['T'],df['R_b'],'bo-')
plt.show()

# %%
df['R']=(df['R_a']+df['R_b'])/2

# %%
plt.figure(figsize=(15,10))
plt.plot(df['T'],df['R'],'go-')
plt.title('R vs T',fontsize=30)
plt.ylabel('R',fontsize=20)
plt.xlabel('T',fontsize=20)
plt.show()
